# %% [markdown]
# #**Deep Learning Homework 2: *Optimize and Train Deep Models***
# ### MSc Computer Science, Data Science, Cybersecurity @UNIPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti, Prof. Nicolò Navarin and Dr. Luca Pasa
# ---
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will learn how to use one of the most popular libraries for Deep Learning, namely [PyTorch 🔥](https://pytorch.org/). Then, we will see how to face a well known problem that is common during the training phase---overfitting on the training set. Finally, we will study how to perform a fair model selection.
#
# <u>Disclaimer</u>: PyTorch is a complex framework actively used by researcher and developers all over the word. It is highly customizable and there are many other packages build along it. The pourpouse of this and the next homeworks is not to go into all the details of its functionalities, but rather to give you an overview of its applications and understand its rationale. There are many good tutorials online and we suggest you to look at the official [Learn the Basics Tutorial](https://pytorch.org/tutorials/beginner/basics/intro.html), in particular if you are not familiar with other Deep Learning Frameworks.
#
# We hope that you will be able to use PyTorch by yourself for your future projects!
# ---
# ##**Important Instructions for Submissions:**
#
# Generally, in the homeworks, you will be either required to complete a part of Python code or to answer questions in text cells. Code and text cells where you are expected to write your answers have been marked by `%STARTCODE` and `%ENDCODE` or `%STARTEXT` and `%ENDTEXT` tags, respectively. Note that you should never change, move or remove these two tags, otherwise your answers will be __not__ valid. As you will see in this notebook, each cell that includes a `[TO COMPLETE]` part has been put between these placeholders.

# %% [markdown]
# ## Requirements

# %% [markdown]
# In this first exercise we will develop a deep feed forward neural network to perform text classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
# They've just released torch 2.0, but we will use the more stable torch=1.13 along with other supporting libriaries
# !pip3 install datasets skorch pandas~=1.5 torch~=1.13 torchinfo torchdata~=0.5 torchtext~=0.14 torchvision~=0.14 torchaudio~=0.13
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 30.9 MB/s eta 0:00:00
# Collecting skorch
#   Downloading skorch-0.12.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas~=1.5 in /usr/local/lib/python3.9/dist-packages (1.5.3)
# Collecting torch~=1.13
#   Downloading torch-1.13.1-cp39-cp39-manylinux1_x86_64.whl (887.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.9 MB/s eta 0:00:00
# Collecting torchinfo
#   Downloading torchinfo-1.7.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: torchdata~=0.5 in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: torchtext~=0.14 in /usr/local/lib/python3.9/dist-packages (0.15.1)
# Requirement already satisfied: torchvision~=0.14 in /usr/local/lib/python3.9/dist-packages (0.15.1+cu118)
# Collecting torchaudio~=0.13
#   Downloading torchaudio-0.13.1-cp39-cp39-manylinux1_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 105.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 79.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 29.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 30.6 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 18.0 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.9/dist-packages (from skorch) (0.8.10)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.9/dist-packages (from skorch) (1.2.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from skorch) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas~=1.5) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas~=1.5) (2.8.2)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 68.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch~=1.13) (4.5.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 77.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (0.40.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (67.6.1)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.9/dist-packages (from torchdata~=0.5) (1.26.15)
# Collecting torchdata~=0.5
#   Downloading torchdata-0.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 93.3 MB/s eta 0:00:00
# Collecting portalocker>=2.0.0
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting torchtext~=0.14
#   Downloading torchtext-0.14.1-cp39-cp39-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 91.9 MB/s eta 0:00:00
# Collecting torchvision~=0.14
#   Downloading torchvision-0.15.1-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 116.5 MB/s eta 0:00:00
#   Downloading torchvision-0.14.1-cp39-cp39-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 65.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision~=0.14) (8.4.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 34.7 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 23.6 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas~=1.5) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.0->skorch) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.0->skorch) (3.1.0)
# Installing collected packages: xxhash, torchinfo, portalocker, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, multidict, frozenlist, dill, async-timeout, yarl, responses, nvidia-cudnn-cu11, multiprocess, huggingface-hub, aiosignal, torch, skorch, aiohttp, torchvision, torchtext, torchdata, torchaudio, datasets
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
#   Attempting uninstall: torchdata
#     Found existing installation: torchdata 0.6.0
#     Uninstalling torchdata-0.6.0:
#       Successfully uninstalled torchdata-0.6.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.1+cu118
#     Uninstalling torchaudio-2.0.1+cu118:
#       Successfully uninstalled torchaudio-2.0.1+cu118
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.4 multidict-6.0.4 multiprocess-0.70.14 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 portalocker-2.7.0 responses-0.18.0 skorch-0.12.1 torch-1.13.1 torchaudio-0.13.1 torchdata-0.5.1 torchinfo-1.7.2 torchtext-0.14.1 torchvision-0.14.1 xxhash-3.2.0 yarl-1.8.2

# %% [markdown]
# ##Imports

# %%
import torch
import torch.nn.functional as F
from torchinfo import summary
from torchtext.datasets import AG_NEWS
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import nn
from sklearn.model_selection import GridSearchCV
from skorch import NeuralNetClassifier 
from skorch.helper import SliceDataset
import multiprocessing
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import logging
import os
from timeit import default_timer as timer

# %%
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

print(f"{torch.__version__=}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"{device=}")
# !nvidia-smi --format=csv --query-gpu=index,name,driver_version,memory.total,memory.used,memory.free

# Set seed for reproducibility
torch.manual_seed(42)
rng = np.random.default_rng(seed=4242)
# Out:
# torch.__version__='1.13.1+cu117'
# device=device(type='cuda')
# index, name, driver_version, memory.total [MiB], memory.used [MiB], memory.free [MiB]
# 0, Tesla T4, 525.85.12, 15360 MiB, 3 MiB, 15098 MiB

# %% [markdown]
# #Data Loading and Preprocessing

# %% [markdown]
# ### Load Data: AG News Subset
#
# In this HW, we use the AG News Subset that is available in Torchtext Datasets. The AG's news topic classification dataset is constructed by choosing the 4 largest topic classes (1-World, 2-Sports, 3-Business, 4-Sci/Tech) from a larger news corpus. The total number of training samples is $120.000$ and testing $7.600$. For resource constraints, we will limit the number of training, validation and test samples to $10.000$, $1.000$ and $1.000$, respectively. Each sample contains both the title and an excerpt of the article, but in this exercise we will use only the excerpt as input.

# %%
train, test = AG_NEWS(root="dataset", split=('train', 'test'))
Tr, Ts = list(train), list(test)
rng.shuffle(Tr)
rng.shuffle(Ts)
len_train, len_val, len_test = 10000, 1000, 1000
train_data, val_data, test_data = Tr[:len_train], Ts[:len_val], Ts[len_val:len_val+len_test]

# %% [markdown]
# And have a look at one sample:

# %%
idx = 10
sample_label, sample_text = train_data[idx]
print(f"Text: {sample_text}")
print(f"Label: {sample_label}")
# Out:
# Text: Vancouver man is victim of shoddy FBI investigation: lawyer (Canadian Press) Canadian Press - VANCOUVER (CP) - A Vancouver man wanted by the U.S. for the 30-year-old murder of an American Indian Movement activist is being persecuted based on a faulty FBI investigation and the word of a troubled drug addict, says the lawyer defending his so-called partner in crime.
# Label: 1

# %% [markdown]
# ### Data Preprocessing
# We will go though the basic data processing building blocks for raw text string.
# Given a string, the first step is to tokenize the data to prepare it as input for the model. For this purpouse, we will use the basic Tokenizer of PyTorch. As you can see, it just normalizes the text, removes whitespaces and unsupported characters, and outputs a list:

# %%
tokenizer = get_tokenizer('basic_english')
print("Example: ", tokenizer("I am so HAPPY to study Deep Learning! #UNIPD #UniLIFE"))
# Out:
# Example:  ['i', 'am', 'so', 'happy', 'to', 'study', 'deep', 'learning', '!', '#unipd', '#unilife']

# %% [markdown]
# The AG News Subset dataset consists in news headlines---sequences of words. We have to encode each sample in a single tensor with a fixed number of elements, we will build a vocabulary of the headlines in our training set. In other words, we tokenize all the training set, and map each unique word into a number (a.k.a. index). This is necesseray as Neural Networks process numbers, so such vocabulary simply translates between readable words and numbers.

# %%
def create_tokens(dataset):
  for sample in dataset:
    yield tokenizer(sample[1])

# We limit our model to learn from the first 1000 most frequent tokens
vocab = build_vocab_from_iterator(create_tokens(train_data), specials=["<unk>"], max_tokens=1000) # <unk> is the index we use for specials characters ...
vocab.set_default_index(vocab["<unk>"]) # ... and as 0 the default values for tokens out of the vocabulary (OOV)
print(f"Our vocabulary is made of {len(vocab)} tokens-index pairs.")
# Out:
# Our vocabulary is made of 1000 tokens-index pairs.

# %% [markdown]
# This vocabulary was build from the training set. Let us see what it does on our example:

# %%
# Let us define some useful functions to handle tokens and labels
text_pipeline = lambda x: vocab(tokenizer(x)) # function to go from string -> tokens
label_pipeline = lambda x: int(x) - 1 # function to label starting form 0 for indexing

# %%
sample_tokenization = text_pipeline(sample_text)
sample_label_idx = label_pipeline(sample_label)

print(f"Samlpe headline text:\n {sample_text}")
print(f"Sample headline to tokens:\n {sample_tokenization}")
print(f"Label:\n {sample_label}")
print(f"Label index:\n {sample_label_idx}")
# Out:
# Samlpe headline text:
#  Vancouver man is victim of shoddy FBI investigation: lawyer (Canadian Press) Canadian Press - VANCOUVER (CP) - A Vancouver man wanted by the U.S. for the 30-year-old murder of an American Indian Movement activist is being persecuted based on a faulty FBI investigation and the word of a troubled drug addict, says the lawyer defending his so-called partner in crime.
# Sample headline to tokens:
#  [0, 415, 23, 0, 6, 0, 0, 963, 0, 13, 313, 262, 14, 313, 262, 15, 0, 13, 780, 14, 15, 5, 0, 415, 0, 24, 2, 51, 1, 9, 1, 11, 2, 0, 0, 6, 31, 159, 637, 0, 0, 23, 264, 0, 0, 10, 5, 0, 0, 963, 8, 2, 0, 6, 5, 0, 380, 0, 3, 82, 2, 0, 0, 34, 0, 0, 7, 0, 1]
# Label:
#  1
# Label index:
#  0

# %% [markdown]
# So each word is correctly mapped into a number, where most frequent words come first (see that the preposition "of", which is very frequent, gets translated to the number $6$). Notice also how "Vancouver" takes the default index value of $0$, meaning that is not frequent in the training set.
#
# Neural Netowrks (usually) take input of fixed size, but news aricles have different lenghts! To tackle this issue, one way is to resort to _multi-hot-encoding_ our dataset, means turning it into a tensor of $0$ and $1$. Concretely, this would mean for instance turning the sequence `[3, 5]` into a $1000$-dimensional vector (our vocabulary) that would be all zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
def multi_hot(token_list, n_cat=len(vocab)):
  encoded = [1 if i in token_list else 0 for i in range(n_cat)]
  return encoded

# %% [markdown]
# The next step is building a PyTorch `DataLoader`. Without going too much into the details, a `DataLoader` is the object one uses in the `for` loops when iterating over the data for training or inference. It has some additional benefits and pourpouses over iterating usual lists, such as multiprocessing, data transformation, sampling or shuffling. Don't worry too much for now, as we do this part for you.

# %%
class AGNewsDataset(Dataset):
  def __init__(self, dataset):
    super().__init__()
    self.dataset = dataset
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    label, text = self.dataset[idx]
    lb = label_pipeline(label)
    txt = multi_hot(text_pipeline(text))
    lb, txt = torch.tensor(lb, dtype=torch.uint8, device=device), torch.tensor(txt, dtype=torch.float32, device=device)
    return lb, txt

# %%
train_dataset = AGNewsDataset(train_data)
val_dataset = AGNewsDataset(val_data)
test_dataset = AGNewsDataset(test_data)

# %%
batch_size = 256
dataloader_training = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
dataloader_validation = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
dataloader_test = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Exercise 2.1: Model Definition and Training
# We can now define the 3-layers feed forward model!
# In PyTorch we do that by subclassing `nn.Module`, and initialize the neural network layers in `__init__`. Every `nn.Module` subclass implements the operations on input data in the `forward` method.
#
# In detail, we created a `FeedforwardNetwork` class. The constructor takes three arguments: `input_dim` (an integer), which is the dimension of the input layer; `num_classes` (an integer), which is the number of output classes; and `hidden_layers_dim` (a list of integers), which is the dimension of the hidden layers in the network.
#
# In the constructor, the `nn.ModuleList() ` object is initialized to hold the layers of the network. If `hidden_layers_dim` is an empty list, then the network only consists of a single linear layer (from input to output). Otherwise, the network consists of multiple linear layers. The first layer goes from the input layer to the first hidden layer, and the subsequent hidden layers go from the previous hidden layer to the next hidden layer. The final output layer goes from the last hidden layer to the output layer.
#
# The `_init_weights` function is a helper function that initializes the weights of the linear layers in the network. It initializes the weights using a normal distribution with a mean of 0 and a standard deviation of 0.1, and sets the biases to zero. Notice that there exist other methods available in the `torch.nn.init` module to initialize layers' weights.
#
# The `forward` function defines the forward pass of the network. It first checks whether the network has only one layer (in which case it simply returns the output of that layer). Otherwise, it applies the `relu` activation function to the output of each hidden layer and passes the result to the next layer. Finally, it returns the output of the final layer. We don't apply the softmax function to the logits produced by the network as this will be done internally in the `CrossEntropyLoss` class, as documented [here](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss).

# %%
class FeedforwardNetwork(nn.Module):
  
  def __init__(self, input_dim, num_classes, hidden_layers_dim=[]):
    super().__init__()
    self.layers = nn.ModuleList()
    if len(hidden_layers_dim) == 0:
      self.layers = self.layers.append(nn.Linear(input_dim, num_classes))
    else:
      for layer_idx in range(len(hidden_layers_dim)):
        if layer_idx == 0:  # first layer, from input to hidden
          self.layers = self.layers.append(nn.Linear(input_dim, hidden_layers_dim[layer_idx]))
        else:  # hidden layers, depending on the input
          self.layers = self.layers.append(nn.Linear(hidden_layers_dim[layer_idx-1], hidden_layers_dim[layer_idx]))
          
      self.layers = self.layers.append(nn.Linear(hidden_layers_dim[-1], num_classes))  # final output layer
    self.apply(self._init_weights)
    
  def _init_weights(self, module):
    if isinstance(module, nn.Linear):
        module.weight.data.normal_(mean=0.0, std=.1)
        if module.bias is not None:
            module.bias.data.zero_()
  
  def forward(self, x):
    if len(self.layers) == 1:
      return self.layers[0](x)
    else:
      for layer in self.layers[:-1]:
        x = F.relu(layer(x))
    return self.layers[-1](x)

# %%
# Now we prepare our model for this specific dataset and exercise
num_class = len(set([label for (label, text) in train_data]))
vocab_size = len(vocab)
EPOCHS = 40
lr = 1e-4
model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[64, 64]).to(device)
summary(model, (batch_size, vocab_size)) # Here is a nice summary of our model!
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# FeedforwardNetwork                       [256, 4]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [256, 64]                 64,064
# │    └─Linear: 2-2                       [256, 64]                 4,160
# │    └─Linear: 2-3                       [256, 4]                  260
# ==========================================================================================
# Total params: 68,484
# Trainable params: 68,484
# Non-trainable params: 0
# Total mult-adds (M): 17.53
# ==========================================================================================
# Input size (MB): 1.02
# Forward/backward pass size (MB): 0.27
# Params size (MB): 0.27
# Estimated Total Size (MB): 1.57
# ==========================================================================================

# %%
# We need to define our loss function (Cross Entropy for multiclass classification) and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# Finally, we can define the training procedure. In PyTorch there are few guidelines to follow to train a model. This time try on your own to understand what each line of code is doing, it will be required for the following HWs and exercises!

# %%
def train(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %% [markdown]
# Let's train it!

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 28.64%, Loss: 1.37913513 ---------------- Val_Acc: 31.20%, Val_Loss: 1.37503576
# epoch: 2 -> Accuracy: 36.15%, Loss: 1.35842133 ---------------- Val_Acc: 37.60%, Val_Loss: 1.35475576
# epoch: 3 -> Accuracy: 43.21%, Loss: 1.33493888 ---------------- Val_Acc: 43.90%, Val_Loss: 1.32880688
# epoch: 4 -> Accuracy: 50.03%, Loss: 1.30309188 ---------------- Val_Acc: 51.20%, Val_Loss: 1.29239726
# epoch: 5 -> Accuracy: 55.87%, Loss: 1.25794160 ---------------- Val_Acc: 58.20%, Val_Loss: 1.24086499
# epoch: 6 -> Accuracy: 61.50%, Loss: 1.19568813 ---------------- Val_Acc: 63.90%, Val_Loss: 1.17141378
# epoch: 7 -> Accuracy: 66.12%, Loss: 1.11570477 ---------------- Val_Acc: 67.90%, Val_Loss: 1.08569670
# epoch: 8 -> Accuracy: 69.60%, Loss: 1.02212441 ---------------- Val_Acc: 71.50%, Val_Loss: 0.99064529
# epoch: 9 -> Accuracy: 72.73%, Loss: 0.92407846 ---------------- Val_Acc: 74.00%, Val_Loss: 0.89694917
# epoch: 10 -> Accuracy: 75.13%, Loss: 0.83106863 ---------------- Val_Acc: 76.30%, Val_Loss: 0.81376761
# epoch: 11 -> Accuracy: 77.04%, Loss: 0.75068587 ---------------- Val_Acc: 76.80%, Val_Loss: 0.74479467
# epoch: 12 -> Accuracy: 78.57%, Loss: 0.68470925 ---------------- Val_Acc: 77.80%, Val_Loss: 0.68973422
# epoch: 13 -> Accuracy: 79.98%, Loss: 0.63159096 ---------------- Val_Acc: 78.40%, Val_Loss: 0.64663410
# epoch: 14 -> Accuracy: 80.91%, Loss: 0.58883625 ---------------- Val_Acc: 79.30%, Val_Loss: 0.61304080
# epoch: 15 -> Accuracy: 81.83%, Loss: 0.55414236 ---------------- Val_Acc: 80.40%, Val_Loss: 0.58655113
# epoch: 16 -> Accuracy: 82.69%, Loss: 0.52551466 ---------------- Val_Acc: 80.70%, Val_Loss: 0.56524336
# epoch: 17 -> Accuracy: 83.39%, Loss: 0.50143409 ---------------- Val_Acc: 80.80%, Val_Loss: 0.54799080
# epoch: 18 -> Accuracy: 83.86%, Loss: 0.48084861 ---------------- Val_Acc: 81.00%, Val_Loss: 0.53393841
# epoch: 19 -> Accuracy: 84.46%, Loss: 0.46304965 ---------------- Val_Acc: 81.60%, Val_Loss: 0.52230698
# epoch: 20 -> Accuracy: 84.92%, Loss: 0.44744045 ---------------- Val_Acc: 82.20%, Val_Loss: 0.51253402
# epoch: 21 -> Accuracy: 85.32%, Loss: 0.43354765 ---------------- Val_Acc: 82.40%, Val_Loss: 0.50428164
# epoch: 22 -> Accuracy: 85.64%, Loss: 0.42106256 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49730524
# epoch: 23 -> Accuracy: 86.00%, Loss: 0.40975380 ---------------- Val_Acc: 83.20%, Val_Loss: 0.49132779
# epoch: 24 -> Accuracy: 86.28%, Loss: 0.39941600 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48617533
# epoch: 25 -> Accuracy: 86.61%, Loss: 0.38991123 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48169667
# epoch: 26 -> Accuracy: 86.89%, Loss: 0.38111496 ---------------- Val_Acc: 83.70%, Val_Loss: 0.47779340
# epoch: 27 -> Accuracy: 87.18%, Loss: 0.37292975 ---------------- Val_Acc: 83.60%, Val_Loss: 0.47439647
# epoch: 28 -> Accuracy: 87.36%, Loss: 0.36526754 ---------------- Val_Acc: 83.40%, Val_Loss: 0.47145891
# epoch: 29 -> Accuracy: 87.59%, Loss: 0.35807091 ---------------- Val_Acc: 83.60%, Val_Loss: 0.46891040
# epoch: 30 -> Accuracy: 87.84%, Loss: 0.35127783 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46671987
# epoch: 31 -> Accuracy: 88.06%, Loss: 0.34484786 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46480390
# epoch: 32 -> Accuracy: 88.30%, Loss: 0.33873680 ---------------- Val_Acc: 83.90%, Val_Loss: 0.46315405
# epoch: 33 -> Accuracy: 88.51%, Loss: 0.33291170 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46172655
# epoch: 34 -> Accuracy: 88.68%, Loss: 0.32734692 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46047717
# epoch: 35 -> Accuracy: 88.77%, Loss: 0.32201678 ---------------- Val_Acc: 84.10%, Val_Loss: 0.45941666
# epoch: 36 -> Accuracy: 88.97%, Loss: 0.31690234 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45856085
# epoch: 37 -> Accuracy: 89.13%, Loss: 0.31198615 ---------------- Val_Acc: 84.80%, Val_Loss: 0.45784882
# epoch: 38 -> Accuracy: 89.30%, Loss: 0.30725285 ---------------- Val_Acc: 84.60%, Val_Loss: 0.45727220
# epoch: 39 -> Accuracy: 89.49%, Loss: 0.30267859 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45683849
# epoch: 40 -> Accuracy: 89.60%, Loss: 0.29826099 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45652449
# Training time in second: 225.32168366300002

# %% [markdown]
# We can now plot these results:

# %%
def plot_learning_acc_and_loss(loss_tr, acc_tr, loss_val, acc_val):
    info = {'loss_training':loss_tr,'acc_trainig':acc_tr, 'loss_validation':loss_val, 'acc_validation':acc_val}
    df = pd.DataFrame(info)
    df.plot(figsize=(8, 10), subplots=[('acc_trainig', 'acc_validation'), ('loss_training','loss_validation')], grid=True)
    plt.xlabel("Epochs")
    plt.show()
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set. By having a look at the previous code, compute the performances on the test set.

# %% [markdown]
# `%STARTCODE`

# %%
model.eval()
total_acc_test, total_count_test, n_batches_test, loss = 0, 0, 0, 0

#[TO COMPLETE]
with torch.no_grad():
  for idx, (label, text) in enumerate(dataloader_test):
    logits = model(text)

    loss += criterion(logits, label)
    n_batches_test += 1

    total_acc_test += (logits.argmax(1) == label).sum().item()
    total_count_test += label.size(0)

loss_test = loss/n_batches_test
accuracy_test = total_acc_test/total_count_test

print(f"Test Loss: {loss_test:.8f}", end=' ---------- ')
print(f"Test Accuracy: {100*accuracy_test:.4f}%")
# Out:
# Test Loss: 0.44434321 ---------- Test Accuracy: 84.3000%

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in the next cell.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# Answer: **[TO COMLPETE]**
#
# We need to understand if our model is overfit or underfit via looking validation set, and if we see some problem we can change model hyperparameters and tune it. We cannot use test set in place of validation set because we also need a set to test our model and it shouldnt be seen by model in the training procedure. Otherwise it could result unfair results. Validation set is useful for detecting overfit or underfit in our model and tuning it.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not much overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %% [markdown]
# ## [TO COMPLETE] Overfitting Model
# In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %% [markdown]
# `%STARTCODE`

# %%
EPOCHS = 50 #[TO COMPLETE]
lr = 0.01 #[TO COMPLETE]
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[64,64,64,64]).to(device) #[TO COMPLETE]
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       64,064
# │    └─Linear: 2-2                       4,160
# │    └─Linear: 2-3                       4,160
# │    └─Linear: 2-4                       4,160
# │    └─Linear: 2-5                       260
# =================================================================
# Total params: 76,804
# Trainable params: 76,804
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 72.12%, Loss: 0.71317476 ---------------- Val_Acc: 79.90%, Val_Loss: 0.55574650
# epoch: 2 -> Accuracy: 87.45%, Loss: 0.36088160 ---------------- Val_Acc: 84.30%, Val_Loss: 0.52518535
# epoch: 3 -> Accuracy: 91.57%, Loss: 0.25136155 ---------------- Val_Acc: 82.40%, Val_Loss: 0.57715744
# epoch: 4 -> Accuracy: 92.24%, Loss: 0.22425032 ---------------- Val_Acc: 81.70%, Val_Loss: 0.65851957
# epoch: 5 -> Accuracy: 93.05%, Loss: 0.20707987 ---------------- Val_Acc: 82.70%, Val_Loss: 0.72032821
# epoch: 6 -> Accuracy: 95.69%, Loss: 0.12578383 ---------------- Val_Acc: 79.00%, Val_Loss: 0.84339583
# epoch: 7 -> Accuracy: 97.39%, Loss: 0.07240924 ---------------- Val_Acc: 79.70%, Val_Loss: 1.13351440
# epoch: 8 -> Accuracy: 98.83%, Loss: 0.03810065 ---------------- Val_Acc: 80.40%, Val_Loss: 1.26682651
# epoch: 9 -> Accuracy: 98.87%, Loss: 0.03519063 ---------------- Val_Acc: 81.50%, Val_Loss: 1.14709604
# epoch: 10 -> Accuracy: 99.26%, Loss: 0.02429565 ---------------- Val_Acc: 80.70%, Val_Loss: 1.37761998
# epoch: 11 -> Accuracy: 99.01%, Loss: 0.02923942 ---------------- Val_Acc: 80.90%, Val_Loss: 1.23333907
# epoch: 12 -> Accuracy: 99.07%, Loss: 0.02782753 ---------------- Val_Acc: 81.70%, Val_Loss: 1.25102603
# epoch: 13 -> Accuracy: 99.28%, Loss: 0.02184472 ---------------- Val_Acc: 80.00%, Val_Loss: 1.31098270
# epoch: 14 -> Accuracy: 99.30%, Loss: 0.02563838 ---------------- Val_Acc: 81.60%, Val_Loss: 1.24286079
# epoch: 15 -> Accuracy: 99.58%, Loss: 0.01495790 ---------------- Val_Acc: 80.90%, Val_Loss: 1.27562714
# epoch: 16 -> Accuracy: 99.60%, Loss: 0.01280250 ---------------- Val_Acc: 81.10%, Val_Loss: 1.41898417
# epoch: 17 -> Accuracy: 99.23%, Loss: 0.02219871 ---------------- Val_Acc: 79.30%, Val_Loss: 1.27963471
# epoch: 18 -> Accuracy: 99.09%, Loss: 0.02715245 ---------------- Val_Acc: 81.00%, Val_Loss: 1.27663517
# epoch: 19 -> Accuracy: 99.17%, Loss: 0.02463740 ---------------- Val_Acc: 79.30%, Val_Loss: 1.69034553
# epoch: 20 -> Accuracy: 99.05%, Loss: 0.02880781 ---------------- Val_Acc: 80.00%, Val_Loss: 1.55016065
# epoch: 21 -> Accuracy: 99.29%, Loss: 0.02241430 ---------------- Val_Acc: 79.80%, Val_Loss: 1.38862252
# epoch: 22 -> Accuracy: 99.72%, Loss: 0.00658162 ---------------- Val_Acc: 80.20%, Val_Loss: 1.61451888
# epoch: 23 -> Accuracy: 99.95%, Loss: 0.00121614 ---------------- Val_Acc: 80.70%, Val_Loss: 1.75827909
# epoch: 24 -> Accuracy: 99.95%, Loss: 0.00269824 ---------------- Val_Acc: 80.20%, Val_Loss: 1.84772933
# epoch: 25 -> Accuracy: 99.98%, Loss: 0.00071686 ---------------- Val_Acc: 81.50%, Val_Loss: 1.80814075
# epoch: 26 -> Accuracy: 99.97%, Loss: 0.00191610 ---------------- Val_Acc: 82.30%, Val_Loss: 1.84076130
# epoch: 27 -> Accuracy: 100.00%, Loss: 0.00012463 ---------------- Val_Acc: 81.90%, Val_Loss: 1.85278559
# epoch: 28 -> Accuracy: 100.00%, Loss: 0.00004615 ---------------- Val_Acc: 82.00%, Val_Loss: 1.88388872
# epoch: 29 -> Accuracy: 100.00%, Loss: 0.00003531 ---------------- Val_Acc: 82.10%, Val_Loss: 1.90955508
# epoch: 30 -> Accuracy: 100.00%, Loss: 0.00002896 ---------------- Val_Acc: 82.00%, Val_Loss: 1.93259156
# epoch: 31 -> Accuracy: 100.00%, Loss: 0.00002461 ---------------- Val_Acc: 82.00%, Val_Loss: 1.95364964
# epoch: 32 -> Accuracy: 100.00%, Loss: 0.00002136 ---------------- Val_Acc: 82.10%, Val_Loss: 1.97309875
# epoch: 33 -> Accuracy: 100.00%, Loss: 0.00001881 ---------------- Val_Acc: 82.10%, Val_Loss: 1.99118662
# epoch: 34 -> Accuracy: 100.00%, Loss: 0.00001674 ---------------- Val_Acc: 82.00%, Val_Loss: 2.00814724
# epoch: 35 -> Accuracy: 100.00%, Loss: 0.00001503 ---------------- Val_Acc: 82.00%, Val_Loss: 2.02410269
# epoch: 36 -> Accuracy: 100.00%, Loss: 0.00001360 ---------------- Val_Acc: 82.00%, Val_Loss: 2.03918123
# epoch: 37 -> Accuracy: 100.00%, Loss: 0.00001238 ---------------- Val_Acc: 82.00%, Val_Loss: 2.05353212
# epoch: 38 -> Accuracy: 100.00%, Loss: 0.00001132 ---------------- Val_Acc: 82.10%, Val_Loss: 2.06721711
# epoch: 39 -> Accuracy: 100.00%, Loss: 0.00001040 ---------------- Val_Acc: 82.00%, Val_Loss: 2.08034968
# epoch: 40 -> Accuracy: 100.00%, Loss: 0.00000960 ---------------- Val_Acc: 82.00%, Val_Loss: 2.09293461
# Training time in second: 216.08197334700003

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.3: $L^1$- and $L^2$-regularization
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \lambda L^p(\theta)
# $$
# where $\lambda$ is a hyperparameter that weighs the relative contribution of the norm penalty $L^p$ on a lernable parameter vector $\theta$:
# $$
#  L^p(\theta)=||\theta||_p=\left(\sum_i |\theta_i|^p\right)^{1/p}
# $$

# %% [markdown]
# In the following blocks you should implement both the $L^1$ and $L^2$ regularization for the overfitting model.
#
# **Disclaimer**: you can implement norms either from scratch (i.e. using simple math operators) or using `torch.linalg` methods, but **not** using implementations embedded in Torch optimizers.

# %% [markdown]
# ### [TO COMPLETE] $L^1$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L1(model, optimizer, dataloader_train, dataloader_val, l1_lambda=0.001, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      sum_of_params = 0.0
      for param in model.parameters():
        if param.requires_grad:
          sum_of_params += torch.sum(torch.abs(param))
      loss_with_l1 = loss + l1_lambda * sum_of_params
      #########################################################
      total_loss_train += loss
      loss_with_l1.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L1(overfit_model, optimizer, dataloader_training, dataloader_validation, l1_lambda=0.001)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 25.82%, Loss: 1.38844764 ---------------- Val_Acc: 30.00%, Val_Loss: 1.36413550
# epoch: 2 -> Accuracy: 31.69%, Loss: 1.36508787 ---------------- Val_Acc: 35.70%, Val_Loss: 1.35015619
# epoch: 3 -> Accuracy: 36.37%, Loss: 1.34918201 ---------------- Val_Acc: 40.80%, Val_Loss: 1.33432770
# epoch: 4 -> Accuracy: 40.95%, Loss: 1.33001471 ---------------- Val_Acc: 45.10%, Val_Loss: 1.31364131
# epoch: 5 -> Accuracy: 45.56%, Loss: 1.30475485 ---------------- Val_Acc: 50.80%, Val_Loss: 1.28513479
# epoch: 6 -> Accuracy: 49.93%, Loss: 1.27126575 ---------------- Val_Acc: 54.40%, Val_Loss: 1.24742079
# epoch: 7 -> Accuracy: 54.05%, Loss: 1.22744226 ---------------- Val_Acc: 57.80%, Val_Loss: 1.19943082
# epoch: 8 -> Accuracy: 57.78%, Loss: 1.17240071 ---------------- Val_Acc: 61.20%, Val_Loss: 1.14126253
# epoch: 9 -> Accuracy: 61.12%, Loss: 1.10761929 ---------------- Val_Acc: 63.70%, Val_Loss: 1.07538247
# epoch: 10 -> Accuracy: 63.95%, Loss: 1.03711200 ---------------- Val_Acc: 66.40%, Val_Loss: 1.00624442
# epoch: 11 -> Accuracy: 66.38%, Loss: 0.96635151 ---------------- Val_Acc: 67.40%, Val_Loss: 0.94052958
# epoch: 12 -> Accuracy: 68.43%, Loss: 0.90169853 ---------------- Val_Acc: 68.60%, Val_Loss: 0.88355267
# epoch: 13 -> Accuracy: 70.36%, Loss: 0.84621018 ---------------- Val_Acc: 70.10%, Val_Loss: 0.83602440
# epoch: 14 -> Accuracy: 71.91%, Loss: 0.79984069 ---------------- Val_Acc: 71.70%, Val_Loss: 0.79707891
# epoch: 15 -> Accuracy: 73.11%, Loss: 0.76126301 ---------------- Val_Acc: 72.80%, Val_Loss: 0.76518899
# epoch: 16 -> Accuracy: 74.28%, Loss: 0.72889161 ---------------- Val_Acc: 74.10%, Val_Loss: 0.73870081
# epoch: 17 -> Accuracy: 75.49%, Loss: 0.70148230 ---------------- Val_Acc: 75.30%, Val_Loss: 0.71640003
# epoch: 18 -> Accuracy: 76.51%, Loss: 0.67792863 ---------------- Val_Acc: 76.00%, Val_Loss: 0.69731081
# epoch: 19 -> Accuracy: 77.34%, Loss: 0.65754402 ---------------- Val_Acc: 76.80%, Val_Loss: 0.68103439
# epoch: 20 -> Accuracy: 77.86%, Loss: 0.63979667 ---------------- Val_Acc: 77.00%, Val_Loss: 0.66691542
# epoch: 21 -> Accuracy: 78.29%, Loss: 0.62419927 ---------------- Val_Acc: 77.60%, Val_Loss: 0.65459812
# epoch: 22 -> Accuracy: 78.84%, Loss: 0.61040759 ---------------- Val_Acc: 77.80%, Val_Loss: 0.64379966
# epoch: 23 -> Accuracy: 79.17%, Loss: 0.59812254 ---------------- Val_Acc: 78.10%, Val_Loss: 0.63421965
# epoch: 24 -> Accuracy: 79.49%, Loss: 0.58715373 ---------------- Val_Acc: 78.40%, Val_Loss: 0.62581545
# epoch: 25 -> Accuracy: 79.82%, Loss: 0.57727695 ---------------- Val_Acc: 78.60%, Val_Loss: 0.61817282
# epoch: 26 -> Accuracy: 80.20%, Loss: 0.56834847 ---------------- Val_Acc: 78.90%, Val_Loss: 0.61136448
# epoch: 27 -> Accuracy: 80.45%, Loss: 0.56029522 ---------------- Val_Acc: 79.10%, Val_Loss: 0.60521096
# epoch: 28 -> Accuracy: 80.73%, Loss: 0.55302483 ---------------- Val_Acc: 79.40%, Val_Loss: 0.59973431
# epoch: 29 -> Accuracy: 81.08%, Loss: 0.54642981 ---------------- Val_Acc: 79.80%, Val_Loss: 0.59477460
# epoch: 30 -> Accuracy: 81.32%, Loss: 0.54036182 ---------------- Val_Acc: 80.00%, Val_Loss: 0.59031278
# epoch: 31 -> Accuracy: 81.64%, Loss: 0.53473920 ---------------- Val_Acc: 80.50%, Val_Loss: 0.58607697
# epoch: 32 -> Accuracy: 81.94%, Loss: 0.52951974 ---------------- Val_Acc: 80.60%, Val_Loss: 0.58216637
# epoch: 33 -> Accuracy: 82.18%, Loss: 0.52468872 ---------------- Val_Acc: 80.80%, Val_Loss: 0.57867777
# epoch: 34 -> Accuracy: 82.32%, Loss: 0.52025193 ---------------- Val_Acc: 81.20%, Val_Loss: 0.57548940
# epoch: 35 -> Accuracy: 82.53%, Loss: 0.51610076 ---------------- Val_Acc: 81.00%, Val_Loss: 0.57253206
# epoch: 36 -> Accuracy: 82.58%, Loss: 0.51222670 ---------------- Val_Acc: 81.10%, Val_Loss: 0.56978732
# epoch: 37 -> Accuracy: 82.69%, Loss: 0.50856608 ---------------- Val_Acc: 81.10%, Val_Loss: 0.56727540
# epoch: 38 -> Accuracy: 82.73%, Loss: 0.50518155 ---------------- Val_Acc: 81.10%, Val_Loss: 0.56501436
# epoch: 39 -> Accuracy: 82.84%, Loss: 0.50197101 ---------------- Val_Acc: 81.00%, Val_Loss: 0.56289828
# epoch: 40 -> Accuracy: 83.04%, Loss: 0.49895707 ---------------- Val_Acc: 81.10%, Val_Loss: 0.56090939
# epoch: 41 -> Accuracy: 83.11%, Loss: 0.49610621 ---------------- Val_Acc: 80.90%, Val_Loss: 0.55892819
# epoch: 42 -> Accuracy: 83.28%, Loss: 0.49340016 ---------------- Val_Acc: 81.00%, Val_Loss: 0.55709696
# epoch: 43 -> Accuracy: 83.40%, Loss: 0.49080688 ---------------- Val_Acc: 81.20%, Val_Loss: 0.55523157
# epoch: 44 -> Accuracy: 83.55%, Loss: 0.48831430 ---------------- Val_Acc: 81.20%, Val_Loss: 0.55343163
# epoch: 45 -> Accuracy: 83.67%, Loss: 0.48589498 ---------------- Val_Acc: 81.70%, Val_Loss: 0.55176854
# epoch: 46 -> Accuracy: 83.75%, Loss: 0.48356768 ---------------- Val_Acc: 81.60%, Val_Loss: 0.55011362
# epoch: 47 -> Accuracy: 83.85%, Loss: 0.48131686 ---------------- Val_Acc: 81.80%, Val_Loss: 0.54851139
# epoch: 48 -> Accuracy: 83.90%, Loss: 0.47911453 ---------------- Val_Acc: 81.90%, Val_Loss: 0.54695415
# epoch: 49 -> Accuracy: 83.98%, Loss: 0.47695461 ---------------- Val_Acc: 82.10%, Val_Loss: 0.54541242
# epoch: 50 -> Accuracy: 84.02%, Loss: 0.47485504 ---------------- Val_Acc: 82.30%, Val_Loss: 0.54391474
# Training time in second: 270.981925317

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# ### [TO COMPLETE] $L^2$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L2(model, optimizer, dataloader_train, dataloader_val, l2_lambda=0.001, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      sum_of_params = 0.0
      for param in model.parameters():
        if param.requires_grad:
          sum_of_params += torch.sum(torch.square(param))
      #sum_of_params = torch.sqrt(sum_of_params)
      loss_with_l2 = loss + l2_lambda * sum_of_params
      ##########################################################
      total_loss_train += loss
      loss_with_l2.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L2(overfit_model, optimizer, dataloader_training, dataloader_validation, l2_lambda=0.01)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 25.31%, Loss: 1.39620054 ---------------- Val_Acc: 24.60%, Val_Loss: 1.38746786
# epoch: 2 -> Accuracy: 29.27%, Loss: 1.37539232 ---------------- Val_Acc: 27.90%, Val_Loss: 1.37306440
# epoch: 3 -> Accuracy: 33.51%, Loss: 1.36180854 ---------------- Val_Acc: 32.00%, Val_Loss: 1.35972381
# epoch: 4 -> Accuracy: 38.11%, Loss: 1.34726405 ---------------- Val_Acc: 35.00%, Val_Loss: 1.34466791
# epoch: 5 -> Accuracy: 43.00%, Loss: 1.32898736 ---------------- Val_Acc: 41.30%, Val_Loss: 1.32482696
# epoch: 6 -> Accuracy: 47.73%, Loss: 1.30389869 ---------------- Val_Acc: 47.00%, Val_Loss: 1.29709601
# epoch: 7 -> Accuracy: 52.66%, Loss: 1.26869786 ---------------- Val_Acc: 53.00%, Val_Loss: 1.25759161
# epoch: 8 -> Accuracy: 57.42%, Loss: 1.22052026 ---------------- Val_Acc: 56.40%, Val_Loss: 1.20392895
# epoch: 9 -> Accuracy: 61.21%, Loss: 1.15726173 ---------------- Val_Acc: 60.60%, Val_Loss: 1.13561416
# epoch: 10 -> Accuracy: 64.37%, Loss: 1.07943618 ---------------- Val_Acc: 64.30%, Val_Loss: 1.05671000
# epoch: 11 -> Accuracy: 67.55%, Loss: 0.99358904 ---------------- Val_Acc: 66.70%, Val_Loss: 0.97663105
# epoch: 12 -> Accuracy: 70.32%, Loss: 0.91084635 ---------------- Val_Acc: 69.80%, Val_Loss: 0.90399712
# epoch: 13 -> Accuracy: 72.77%, Loss: 0.83760911 ---------------- Val_Acc: 71.70%, Val_Loss: 0.84179175
# epoch: 14 -> Accuracy: 74.73%, Loss: 0.77552807 ---------------- Val_Acc: 73.90%, Val_Loss: 0.79032910
# epoch: 15 -> Accuracy: 76.41%, Loss: 0.72403795 ---------------- Val_Acc: 75.40%, Val_Loss: 0.74843341
# epoch: 16 -> Accuracy: 77.80%, Loss: 0.68171436 ---------------- Val_Acc: 76.60%, Val_Loss: 0.71454990
# epoch: 17 -> Accuracy: 78.93%, Loss: 0.64683837 ---------------- Val_Acc: 77.50%, Val_Loss: 0.68692911
# epoch: 18 -> Accuracy: 80.03%, Loss: 0.61788076 ---------------- Val_Acc: 78.20%, Val_Loss: 0.66413039
# epoch: 19 -> Accuracy: 81.04%, Loss: 0.59349036 ---------------- Val_Acc: 78.50%, Val_Loss: 0.64513028
# epoch: 20 -> Accuracy: 81.68%, Loss: 0.57265168 ---------------- Val_Acc: 79.20%, Val_Loss: 0.62910348
# epoch: 21 -> Accuracy: 82.17%, Loss: 0.55468088 ---------------- Val_Acc: 80.30%, Val_Loss: 0.61551017
# epoch: 22 -> Accuracy: 82.72%, Loss: 0.53900450 ---------------- Val_Acc: 80.40%, Val_Loss: 0.60377252
# epoch: 23 -> Accuracy: 83.23%, Loss: 0.52524137 ---------------- Val_Acc: 80.70%, Val_Loss: 0.59348089
# epoch: 24 -> Accuracy: 83.69%, Loss: 0.51309234 ---------------- Val_Acc: 81.40%, Val_Loss: 0.58443230
# epoch: 25 -> Accuracy: 84.10%, Loss: 0.50223970 ---------------- Val_Acc: 81.60%, Val_Loss: 0.57643425
# epoch: 26 -> Accuracy: 84.47%, Loss: 0.49249101 ---------------- Val_Acc: 82.10%, Val_Loss: 0.56929290
# epoch: 27 -> Accuracy: 84.79%, Loss: 0.48371610 ---------------- Val_Acc: 82.40%, Val_Loss: 0.56293750
# epoch: 28 -> Accuracy: 85.03%, Loss: 0.47575068 ---------------- Val_Acc: 82.30%, Val_Loss: 0.55712640
# epoch: 29 -> Accuracy: 85.32%, Loss: 0.46845588 ---------------- Val_Acc: 82.40%, Val_Loss: 0.55183959
# epoch: 30 -> Accuracy: 85.51%, Loss: 0.46176225 ---------------- Val_Acc: 82.50%, Val_Loss: 0.54701483
# epoch: 31 -> Accuracy: 85.73%, Loss: 0.45562044 ---------------- Val_Acc: 82.40%, Val_Loss: 0.54254448
# epoch: 32 -> Accuracy: 85.92%, Loss: 0.44997510 ---------------- Val_Acc: 82.60%, Val_Loss: 0.53852260
# epoch: 33 -> Accuracy: 86.12%, Loss: 0.44477510 ---------------- Val_Acc: 83.00%, Val_Loss: 0.53478462
# epoch: 34 -> Accuracy: 86.22%, Loss: 0.43995330 ---------------- Val_Acc: 83.10%, Val_Loss: 0.53133237
# epoch: 35 -> Accuracy: 86.34%, Loss: 0.43548200 ---------------- Val_Acc: 82.80%, Val_Loss: 0.52810764
# epoch: 36 -> Accuracy: 86.49%, Loss: 0.43130729 ---------------- Val_Acc: 82.90%, Val_Loss: 0.52515209
# epoch: 37 -> Accuracy: 86.58%, Loss: 0.42743310 ---------------- Val_Acc: 83.00%, Val_Loss: 0.52228487
# epoch: 38 -> Accuracy: 86.73%, Loss: 0.42376176 ---------------- Val_Acc: 83.10%, Val_Loss: 0.51966858
# epoch: 39 -> Accuracy: 86.85%, Loss: 0.42034173 ---------------- Val_Acc: 83.10%, Val_Loss: 0.51720977
# epoch: 40 -> Accuracy: 86.93%, Loss: 0.41711879 ---------------- Val_Acc: 83.00%, Val_Loss: 0.51489931
# Training time in second: 226.7663037279999

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.4: Early Stopping
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (a.k.a. the "patience" or "tolerance" hyper-parameter), it stops the training phase.
#
# To implement it in PyTorch, we define a simple classes that does this job.

# %%
class EarlyStopping:
    def __init__(self, tolerance, min_delta):
        self.tolerance = tolerance
        self.min_delta = min_delta
        self.counter = 0
        self.early_stop = False

    def __call__(self, train_loss, validation_loss):
        if (validation_loss - train_loss) > self.min_delta:
            self.counter +=1
            if self.counter >= self.tolerance:  
                self.early_stop = True

# %% [markdown]
# ## **[TO COMPLETE]**: Define training procedure
# Define a training procedure with Early Stopping and check its performances.

# %% [markdown]
# `%STARTCODE`

# %%
def train_early_stop(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  ###########################################################
  # instantiate an object of the EarlyStopping class 
  #[TO COMPLETE]
  early_stopping = EarlyStopping(5, 0.01)
  ###########################################################
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
    ############################################################
    # Use the EarlyStopping object
    #[TO COMPLETE]
    early_stopping(avg_loss_train, avg_loss_val)
    if early_stopping.early_stop:
      print("early stopping at epoch: ", epoch)
      break
    ############################################################
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_early_stop(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 30.61%, Loss: 1.36897266 ---------------- Val_Acc: 38.90%, Val_Loss: 1.33640409
# epoch: 2 -> Accuracy: 46.08%, Loss: 1.29752576 ---------------- Val_Acc: 52.50%, Val_Loss: 1.26527297
# epoch: 3 -> Accuracy: 57.03%, Loss: 1.20491111 ---------------- Val_Acc: 62.00%, Val_Loss: 1.16189694
# epoch: 4 -> Accuracy: 65.13%, Loss: 1.07536924 ---------------- Val_Acc: 67.90%, Val_Loss: 1.02534604
# epoch: 5 -> Accuracy: 71.96%, Loss: 0.92142886 ---------------- Val_Acc: 72.20%, Val_Loss: 0.88044268
# epoch: 6 -> Accuracy: 75.94%, Loss: 0.77346158 ---------------- Val_Acc: 73.80%, Val_Loss: 0.75841761
# epoch: 7 -> Accuracy: 78.85%, Loss: 0.65520352 ---------------- Val_Acc: 76.00%, Val_Loss: 0.67273426
# epoch: 8 -> Accuracy: 81.02%, Loss: 0.57112163 ---------------- Val_Acc: 77.20%, Val_Loss: 0.61868036
# epoch: 9 -> Accuracy: 82.92%, Loss: 0.51230896 ---------------- Val_Acc: 78.30%, Val_Loss: 0.58479720
# epoch: 10 -> Accuracy: 84.32%, Loss: 0.46892649 ---------------- Val_Acc: 79.30%, Val_Loss: 0.56212831
# epoch: 11 -> Accuracy: 85.33%, Loss: 0.43475404 ---------------- Val_Acc: 79.50%, Val_Loss: 0.54585731
# early stopping at epoch:  10
# Training time in second: 59.4382638540003

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Model Selection
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-5, 1e-4, 1e-3]

# %%
stack = []
for lr in learning_rates:
  print(f"Learning Rate: {lr}")
  model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[128, 64]).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr=lr)
  stack.append(train(model, optimizer, dataloader_training, dataloader_validation, EPOCHS=15))
  print("-"*50)
# Out:
# Learning Rate: 1e-05
# epoch: 1 -> Accuracy: 27.11%, Loss: 1.38511086 ---------------- Val_Acc: 27.90%, Val_Loss: 1.38034821
# epoch: 2 -> Accuracy: 27.85%, Loss: 1.38058782 ---------------- Val_Acc: 28.40%, Val_Loss: 1.37661219
# epoch: 3 -> Accuracy: 28.54%, Loss: 1.37637162 ---------------- Val_Acc: 28.90%, Val_Loss: 1.37299800
# epoch: 4 -> Accuracy: 29.35%, Loss: 1.37228799 ---------------- Val_Acc: 29.80%, Val_Loss: 1.36946011
# epoch: 5 -> Accuracy: 30.10%, Loss: 1.36829317 ---------------- Val_Acc: 30.60%, Val_Loss: 1.36597574
# epoch: 6 -> Accuracy: 31.06%, Loss: 1.36435080 ---------------- Val_Acc: 31.30%, Val_Loss: 1.36251330
# epoch: 7 -> Accuracy: 31.77%, Loss: 1.36042750 ---------------- Val_Acc: 32.30%, Val_Loss: 1.35905051
# epoch: 8 -> Accuracy: 32.85%, Loss: 1.35650289 ---------------- Val_Acc: 32.90%, Val_Loss: 1.35556185
# epoch: 9 -> Accuracy: 34.07%, Loss: 1.35257161 ---------------- Val_Acc: 33.50%, Val_Loss: 1.35204411
# epoch: 10 -> Accuracy: 34.86%, Loss: 1.34861970 ---------------- Val_Acc: 34.00%, Val_Loss: 1.34848392
# epoch: 11 -> Accuracy: 35.90%, Loss: 1.34463108 ---------------- Val_Acc: 35.60%, Val_Loss: 1.34486175
# epoch: 12 -> Accuracy: 36.78%, Loss: 1.34060383 ---------------- Val_Acc: 36.60%, Val_Loss: 1.34117794
# epoch: 13 -> Accuracy: 37.78%, Loss: 1.33650959 ---------------- Val_Acc: 37.30%, Val_Loss: 1.33742213
# epoch: 14 -> Accuracy: 38.76%, Loss: 1.33233130 ---------------- Val_Acc: 38.20%, Val_Loss: 1.33358359
# epoch: 15 -> Accuracy: 39.48%, Loss: 1.32807004 ---------------- Val_Acc: 39.30%, Val_Loss: 1.32965362
# --------------------------------------------------
# Learning Rate: 0.0001
# epoch: 1 -> Accuracy: 26.27%, Loss: 1.38954198 ---------------- Val_Acc: 32.10%, Val_Loss: 1.36511302
# epoch: 2 -> Accuracy: 35.46%, Loss: 1.35473287 ---------------- Val_Acc: 39.20%, Val_Loss: 1.33272958
# epoch: 3 -> Accuracy: 44.84%, Loss: 1.31773078 ---------------- Val_Acc: 47.30%, Val_Loss: 1.29304028
# epoch: 4 -> Accuracy: 53.46%, Loss: 1.26980078 ---------------- Val_Acc: 56.60%, Val_Loss: 1.23918962
# epoch: 5 -> Accuracy: 61.15%, Loss: 1.20463073 ---------------- Val_Acc: 61.60%, Val_Loss: 1.16612029
# epoch: 6 -> Accuracy: 67.57%, Loss: 1.11785543 ---------------- Val_Acc: 67.40%, Val_Loss: 1.07193208
# epoch: 7 -> Accuracy: 72.00%, Loss: 1.01027405 ---------------- Val_Acc: 70.90%, Val_Loss: 0.96322894
# epoch: 8 -> Accuracy: 75.46%, Loss: 0.89306957 ---------------- Val_Acc: 74.20%, Val_Loss: 0.85462832
# epoch: 9 -> Accuracy: 77.62%, Loss: 0.78471631 ---------------- Val_Acc: 76.50%, Val_Loss: 0.76178634
# epoch: 10 -> Accuracy: 79.38%, Loss: 0.69579351 ---------------- Val_Acc: 78.00%, Val_Loss: 0.68982005
# epoch: 11 -> Accuracy: 80.60%, Loss: 0.62705088 ---------------- Val_Acc: 79.40%, Val_Loss: 0.63661754
# epoch: 12 -> Accuracy: 81.75%, Loss: 0.57463807 ---------------- Val_Acc: 80.30%, Val_Loss: 0.59741282
# epoch: 13 -> Accuracy: 82.73%, Loss: 0.53406090 ---------------- Val_Acc: 81.30%, Val_Loss: 0.56776005
# epoch: 14 -> Accuracy: 83.53%, Loss: 0.50158089 ---------------- Val_Acc: 81.90%, Val_Loss: 0.54509300
# epoch: 15 -> Accuracy: 84.25%, Loss: 0.47496223 ---------------- Val_Acc: 82.30%, Val_Loss: 0.52759427
# --------------------------------------------------
# Learning Rate: 0.001
# epoch: 1 -> Accuracy: 55.87%, Loss: 1.13242435 ---------------- Val_Acc: 74.00%, Val_Loss: 0.78216320
# epoch: 2 -> Accuracy: 80.77%, Loss: 0.56726903 ---------------- Val_Acc: 82.30%, Val_Loss: 0.51493406
# epoch: 3 -> Accuracy: 85.93%, Loss: 0.39826477 ---------------- Val_Acc: 82.90%, Val_Loss: 0.47296536
# epoch: 4 -> Accuracy: 88.59%, Loss: 0.32514092 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46048942
# epoch: 5 -> Accuracy: 90.56%, Loss: 0.27431443 ---------------- Val_Acc: 84.50%, Val_Loss: 0.46359202
# epoch: 6 -> Accuracy: 92.37%, Loss: 0.23297489 ---------------- Val_Acc: 84.40%, Val_Loss: 0.47711539
# epoch: 7 -> Accuracy: 93.83%, Loss: 0.19644299 ---------------- Val_Acc: 84.10%, Val_Loss: 0.49868104
# epoch: 8 -> Accuracy: 95.33%, Loss: 0.16300921 ---------------- Val_Acc: 83.50%, Val_Loss: 0.52559513
# epoch: 9 -> Accuracy: 96.38%, Loss: 0.13207637 ---------------- Val_Acc: 82.60%, Val_Loss: 0.56089693
# epoch: 10 -> Accuracy: 97.62%, Loss: 0.10353767 ---------------- Val_Acc: 82.40%, Val_Loss: 0.60387266
# epoch: 11 -> Accuracy: 98.61%, Loss: 0.07902530 ---------------- Val_Acc: 82.20%, Val_Loss: 0.65466726
# epoch: 12 -> Accuracy: 99.11%, Loss: 0.05949089 ---------------- Val_Acc: 82.50%, Val_Loss: 0.70592600
# epoch: 13 -> Accuracy: 99.38%, Loss: 0.04580323 ---------------- Val_Acc: 82.50%, Val_Loss: 0.73899800
# epoch: 14 -> Accuracy: 99.55%, Loss: 0.03795859 ---------------- Val_Acc: 82.90%, Val_Loss: 0.75862980
# epoch: 15 -> Accuracy: 99.61%, Loss: 0.03464141 ---------------- Val_Acc: 82.60%, Val_Loss: 0.79289180
# --------------------------------------------------

# %%
# Let's plot the results
for idx, el in enumerate(stack):
  print(f"Learning Rate: {learning_rates[idx]}")
  plot_learning_acc_and_loss(*el)
# Out:
# Learning Rate: 1e-05
# Learning Rate: 0.0001
# Learning Rate: 0.001

# %% [markdown]
# # Exercise 2.5: Grid Search
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider different possible combinations of values for each hyper-parameter. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be selected.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`, together with some classes from the `skorch` package which allows to use PyTorch models with `scikit-learn`.

# %%
model = NeuralNetClassifier(
    module=FeedforwardNetwork,
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.Adam,
    max_epochs=2)

# we need to adapt PyTorch Dataset to work with Scikit-Learn GridSearchCV
# we use the SliceDataset class from skorch package for this purpose
X_slice = SliceDataset(train_dataset, idx=1)
y_slice = SliceDataset(train_dataset, idx=0)

# %% [markdown]
# ## **[TO COMPLETE]**: Define hyperparameters grid

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use dictionaries of very limited size and hyperparameters, but in a real-world scenario a reasonable amount of possible values should be considered (and there are many other approacehs besisdes Grid-Search).

# %% [markdown]
# `%STARTCODE`

# %%
params = {
    'lr': [1e-5, 1e-4, 1e-3], #[TO COMPLETE],
    'module__input_dim': [vocab_size], #[TO COMPLETE],
    'module__num_classes': [num_class], #[TO COMPLETE],
    'module__hidden_layers_dim':[[128, 64]] #[TO COMPLETE], 
    }

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Now you can use `sklearn`'s `GridSearchCV` to search the hyperparameter space of the `NeuralNetClassifier`:

# %%
n_jobs = multiprocessing.cpu_count()-1
gs = GridSearchCV(model, params, n_jobs=n_jobs)

# %%
outputs = gs.fit(X_slice, y_slice)
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.4280       0.2637        1.4211  9.0358
#       2        1.4182       0.2669        1.4125  7.3849
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.4027       0.2500        1.4055  7.6298
#       2        1.3969       0.2562        1.4005  9.2535
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3953       0.2644        1.3927  9.1407
#       2        1.3905       0.2700        1.3888  7.7043
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3966       0.2675        1.3948  9.3130
#       2        1.3916       0.2769        1.3907  9.2978
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3961       0.2306        1.3941  8.0547
#       2        1.3931       0.2369        1.3916  8.9991
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3830       0.3475        1.3554  9.3826
#       2        1.3398       0.4500        1.3163  8.6123
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3827       0.3200        1.3663  7.7118
#       2        1.3428       0.4169        1.3299  9.2843
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3768       0.3438        1.3585  8.9109
#       2        1.3345       0.4269        1.3206  7.2485
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3924       0.3175        1.3710  8.3028
#       2        1.3528       0.4025        1.3381  9.0160
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3767       0.3387        1.3595  7.8518
#       2        1.3311       0.4356        1.3174  8.3419
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1640       0.7594        0.7993  9.0867
#       2        0.5642       0.8244        0.5112  7.8730
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1718       0.7262        0.8362  7.1812
#       2        0.5619       0.8087        0.5210  9.0380
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1783       0.7400        0.8237  9.0013
#       2        0.5509       0.8169        0.5143  7.2985
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.2092       0.7175        0.9000  9.0374
#       2        0.5917       0.8125        0.5267  9.2334
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1354       0.7375        0.7969  7.4178
#       2        0.5633       0.8119        0.5072  9.2026
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.0641       0.7695        0.6776  11.1984
#       2        0.4921       0.8170        0.4953  10.9130

# %% [markdown]
# ## **[TO COMPLETE]**: Visualize results
# Print the best hyper-parameters and the performances on the best model on the test set:

# %% [markdown]
# `%STARTCODE`

# %%
print("best score: {:.3f}, best params: {}".format(gs.best_score_, gs.best_params_)) #[TO COMPLETE]
# Out:
# best score: 0.821, best params: {'lr': 0.001, 'module__hidden_layers_dim': [128, 64], 'module__input_dim': 1000, 'module__num_classes': 4}

# %%
gs.best_estimator_.predict_proba(text)
# Out:
# array([[6.90972619e-03, 3.66075858e-02, 2.28369832e-02, 9.33645725e-01],
#        [2.20222250e-02, 8.30529153e-01, 3.57866241e-03, 1.43869907e-01],
#        [1.44872488e-03, 9.98395026e-01, 3.47106688e-05, 1.21544224e-04],
#        [8.62951219e-01, 3.17066386e-02, 3.99476439e-02, 6.53945133e-02],
#        [1.67261343e-02, 9.79945660e-01, 5.25710697e-04, 2.80257640e-03],
#        [1.18012493e-02, 2.82046705e-01, 1.30258268e-02, 6.93126142e-01],
#        [7.36080064e-03, 4.36351780e-04, 9.04770315e-01, 8.74324515e-02],
#        [5.03619686e-02, 6.79231307e-05, 9.31956470e-01, 1.76136717e-02],
#        [9.89064395e-01, 8.19113571e-04, 8.26938543e-03, 1.84714678e-03],
#        [9.91337538e-01, 4.16331459e-03, 3.43607645e-03, 1.06296875e-03],
#        [8.21263611e-01, 3.20361403e-04, 1.68365330e-01, 1.00507885e-02],
#        [3.96827934e-03, 9.94974494e-01, 3.24657885e-04, 7.32669607e-04],
#        [9.59779382e-01, 6.91123446e-03, 3.20360623e-02, 1.27336429e-03],
#        [4.19892557e-02, 8.62564504e-01, 3.62194441e-02, 5.92267476e-02],
#        [2.61111334e-02, 9.85029183e-05, 9.67445731e-01, 6.34462386e-03],
#        [9.91098940e-01, 4.93274396e-03, 2.68269866e-03, 1.28565228e-03],
#        [4.71859388e-02, 9.27919865e-01, 8.04845616e-03, 1.68457385e-02],
#        [8.52675270e-03, 7.77448440e-05, 9.80373740e-01, 1.10216970e-02],
#        [9.86265112e-03, 9.87979412e-01, 2.33819112e-04, 1.92417006e-03],
#        [3.43516618e-02, 9.53880370e-01, 5.65773668e-03, 6.11030869e-03],
#        [2.91617162e-05, 3.45793051e-05, 1.53160766e-02, 9.84620214e-01],
#        [1.34437103e-02, 1.11756213e-02, 3.81552994e-01, 5.93827665e-01],
#        [2.64952239e-03, 9.95739937e-01, 1.13062611e-04, 1.49748276e-03],
#        [4.32238765e-02, 9.27685261e-01, 1.08379535e-02, 1.82529166e-02],
#        [8.57771754e-01, 1.60546247e-02, 6.51348531e-02, 6.10386766e-02],
#        [1.37648480e-02, 7.03104306e-04, 9.13615286e-01, 7.19168484e-02],
#        [3.22763622e-01, 1.37377821e-03, 2.46829197e-01, 4.29033369e-01],
#        [6.69857800e-01, 7.57890288e-03, 1.45724982e-01, 1.76838383e-01],
#        [8.56819600e-02, 4.70476598e-01, 2.82216556e-02, 4.15619820e-01],
#        [2.29504760e-02, 5.50899515e-03, 9.08808351e-01, 6.27321303e-02],
#        [1.60598122e-02, 1.40689022e-03, 7.31809139e-01, 2.50724137e-01],
#        [7.25422382e-01, 1.36912791e-02, 1.51098222e-01, 1.09788120e-01],
#        [4.03793762e-03, 9.95110452e-01, 8.15754684e-05, 7.69996725e-04],
#        [2.55412236e-02, 7.65662361e-03, 1.27464995e-01, 8.39337230e-01],
#        [3.83891957e-03, 1.84273580e-03, 7.17848912e-02, 9.22533453e-01],
#        [5.52647107e-04, 3.20626516e-03, 3.39425504e-02, 9.62298512e-01],
#        [9.99083877e-01, 2.44146446e-04, 5.09073900e-04, 1.62933415e-04],
#        [3.92835513e-02, 8.78095984e-01, 1.49947535e-02, 6.76256940e-02],
#        [9.97639775e-01, 6.96918811e-04, 6.42144412e-04, 1.02127518e-03],
#        [1.64623912e-02, 1.75897758e-02, 5.97277641e-01, 3.68670166e-01],
#        [1.13427527e-02, 4.37156923e-05, 9.65552390e-01, 2.30612122e-02],
#        [9.95103478e-01, 4.68768529e-04, 3.26789590e-03, 1.15981442e-03],
#        [4.07427037e-03, 3.57392491e-05, 5.53045452e-01, 4.42844570e-01],
#        [6.99121878e-02, 2.00002175e-03, 9.17513371e-01, 1.05744414e-02],
#        [6.86571673e-02, 2.11275741e-02, 1.02462620e-01, 8.07752609e-01],
#        [1.39803416e-03, 4.76104877e-04, 5.44720471e-01, 4.53405470e-01],
#        [5.57708144e-01, 4.34692800e-01, 4.42930032e-03, 3.16974823e-03],
#        [1.41426772e-01, 5.96663877e-02, 5.49787104e-01, 2.49119639e-01],
#        [2.00065275e-04, 3.19451965e-06, 7.15240419e-01, 2.84556299e-01],
#        [2.66890265e-02, 9.70416784e-01, 4.54804103e-04, 2.43934710e-03],
#        [9.36992094e-03, 8.67451280e-02, 9.90522467e-03, 8.93979728e-01],
#        [3.51110240e-03, 3.08642443e-03, 3.59221883e-02, 9.57480252e-01],
#        [5.31680649e-03, 2.92014302e-04, 7.58395672e-01, 2.35995501e-01],
#        [2.44106948e-02, 7.71126244e-04, 9.31867719e-01, 4.29504365e-02],
#        [1.36657640e-01, 3.75513285e-01, 1.48824096e-01, 3.39004993e-01],
#        [4.51690052e-03, 9.91436899e-01, 4.87832673e-04, 3.55824595e-03],
#        [7.48294266e-03, 5.53690828e-03, 1.12707511e-01, 8.74272585e-01],
#        [8.18048343e-02, 8.10244307e-02, 8.71131495e-02, 7.50057578e-01],
#        [7.79312730e-01, 1.04315691e-02, 1.74063966e-01, 3.61916870e-02],
#        [2.82803178e-03, 9.95746911e-01, 6.33983058e-04, 7.91070575e-04],
#        [2.48327494e-01, 1.19101733e-01, 2.19256058e-01, 4.13314700e-01],
#        [1.09092111e-03, 1.25603356e-06, 9.97465730e-01, 1.44212833e-03],
#        [1.59704499e-02, 9.38323140e-01, 6.57157460e-03, 3.91347967e-02],
#        [6.13333468e-05, 2.66500592e-07, 9.95901406e-01, 4.03695041e-03],
#        [2.45629065e-02, 9.28310454e-01, 1.11632710e-02, 3.59633304e-02],
#        [9.65804160e-01, 9.84735508e-03, 1.72037780e-02, 7.14479061e-03],
#        [1.79612283e-02, 2.91497330e-04, 9.78649855e-01, 3.09739099e-03],
#        [7.95268297e-01, 4.24616365e-03, 1.46647781e-01, 5.38376495e-02],
#        [3.24806519e-04, 8.99828319e-06, 8.97942960e-01, 1.01723269e-01],
#        [1.97408590e-02, 7.71761057e-04, 9.72641945e-01, 6.84548914e-03],
#        [8.61861467e-01, 5.45553025e-03, 1.13623671e-01, 1.90592948e-02],
#        [1.19123571e-02, 5.36592794e-04, 6.65055990e-01, 3.22495103e-01],
#        [9.54304934e-02, 8.91030848e-01, 2.82452255e-03, 1.07141724e-02],
#        [4.35603172e-01, 1.08824447e-01, 3.83138061e-02, 4.17258590e-01],
#        [9.90081728e-02, 7.73571670e-01, 8.55745524e-02, 4.18456458e-02],
#        [2.09037957e-04, 3.06532854e-07, 9.93030250e-01, 6.76048873e-03],
#        [1.20950658e-02, 3.75830350e-05, 9.38813329e-01, 4.90540452e-02],
#        [9.93762791e-01, 2.16300483e-03, 2.77716783e-03, 1.29705493e-03],
#        [6.06153719e-02, 8.89946759e-01, 1.51483100e-02, 3.42896134e-02],
#        [8.19703192e-02, 1.41271378e-03, 3.10952336e-01, 6.05664670e-01],
#        [4.95715171e-01, 1.05331779e-01, 2.00037599e-01, 1.98915437e-01],
#        [2.26723813e-02, 9.44846809e-01, 9.97529831e-03, 2.25055292e-02],
#        [6.62471503e-02, 9.09699738e-01, 1.05100563e-02, 1.35431346e-02],
#        [1.53931677e-01, 5.41814081e-02, 8.81740823e-02, 7.03712881e-01],
#        [2.91171372e-01, 4.30592261e-02, 2.64122933e-01, 4.01646465e-01],
#        [1.37334079e-01, 2.18158349e-01, 1.74655542e-01, 4.69852060e-01],
#        [1.62291124e-01, 4.67135087e-02, 9.01807249e-02, 7.00814605e-01],
#        [7.67547265e-02, 2.76916653e-01, 9.06361341e-02, 5.55692494e-01],
#        [2.90361904e-02, 9.36631322e-01, 4.51617083e-03, 2.98164450e-02],
#        [1.03069777e-02, 5.45819476e-03, 5.63877597e-02, 9.27847087e-01],
#        [8.27565670e-01, 5.85292950e-02, 7.27881640e-02, 4.11168709e-02],
#        [2.66926410e-03, 9.83554661e-01, 1.19403750e-03, 1.25819668e-02],
#        [1.56455368e-01, 7.62376726e-01, 4.64837905e-03, 7.65194744e-02],
#        [2.25103330e-02, 7.21789181e-01, 4.39697318e-02, 2.11730748e-01],
#        [5.22499561e-01, 3.44061814e-02, 2.06226826e-01, 2.36867443e-01],
#        [4.53855097e-02, 8.87320578e-01, 1.77512895e-02, 4.95427586e-02],
#        [9.73822594e-01, 5.75580588e-03, 1.55723812e-02, 4.84928116e-03],
#        [5.83544314e-01, 1.22928582e-01, 2.28379685e-02, 2.70689160e-01],
#        [7.76343560e-03, 9.81055260e-01, 4.60396474e-03, 6.57735392e-03],
#        [9.03367579e-01, 8.42264481e-03, 5.05629815e-02, 3.76468226e-02],
#        [5.70639312e-01, 1.05873421e-01, 7.91039541e-02, 2.44383365e-01],
#        [1.04393773e-01, 1.81633644e-02, 1.64407060e-01, 7.13035822e-01],
#        [6.37969449e-02, 6.09911680e-01, 8.66396800e-02, 2.39651784e-01],
#        [7.17666224e-02, 5.00974013e-03, 6.53304219e-01, 2.69919336e-01],
#        [4.21013147e-01, 8.52143764e-03, 4.97458458e-01, 7.30070546e-02],
#        [1.70856137e-02, 9.77664053e-01, 8.85577465e-04, 4.36480762e-03],
#        [2.76919082e-02, 5.12590108e-04, 8.31694663e-01, 1.40100867e-01],
#        [5.98367989e-01, 6.50182664e-02, 5.02186529e-02, 2.86395043e-01],
#        [1.04818977e-02, 9.88570631e-01, 1.14022958e-04, 8.33394413e-04],
#        [2.72836946e-02, 9.39300776e-01, 7.76875857e-03, 2.56468207e-02],
#        [8.35100532e-01, 3.38732190e-02, 5.14041260e-02, 7.96221569e-02],
#        [2.69037765e-03, 2.00563227e-03, 1.19424239e-01, 8.75879765e-01],
#        [9.99795854e-01, 7.23349876e-05, 1.12472146e-04, 1.93490869e-05],
#        [9.53102410e-01, 4.15845215e-03, 2.18379423e-02, 2.09012050e-02],
#        [2.28072889e-03, 1.69906169e-04, 6.88419759e-01, 3.09129596e-01],
#        [7.14556098e-01, 2.48821229e-02, 8.73319656e-02, 1.73229799e-01],
#        [9.97179896e-02, 2.11349711e-01, 5.21086812e-01, 1.67845443e-01],
#        [7.08222464e-02, 8.28905264e-04, 8.98896396e-01, 2.94524878e-02],
#        [6.34011269e-01, 1.56319827e-01, 1.36144593e-01, 7.35243410e-02],
#        [7.62160588e-03, 9.83862817e-01, 2.45074276e-03, 6.06485456e-03],
#        [9.93466437e-01, 1.64459122e-03, 3.21645127e-03, 1.67252857e-03],
#        [3.75121090e-05, 2.36656987e-07, 9.98371184e-01, 1.59106357e-03],
#        [5.35887539e-01, 4.04542714e-01, 1.14583476e-02, 4.81114015e-02],
#        [3.18244994e-01, 2.65107513e-03, 1.58643737e-01, 5.20460129e-01],
#        [3.64586055e-01, 4.20306735e-02, 1.17485419e-01, 4.75897878e-01],
#        [1.86993033e-02, 9.35613930e-01, 4.37465822e-03, 4.13119905e-02],
#        [2.85859010e-03, 9.93778527e-01, 5.25381009e-04, 2.83741998e-03],
#        [9.95873749e-01, 1.51494882e-04, 2.04764795e-03, 1.92708499e-03],
#        [4.72490152e-04, 9.99283016e-01, 1.09039705e-04, 1.35617229e-04],
#        [2.07874216e-02, 9.78075922e-01, 3.21833562e-04, 8.14910105e-04],
#        [2.02670228e-03, 9.97704923e-01, 1.33386231e-04, 1.35098933e-04],
#        [4.77077148e-04, 3.61110293e-03, 1.88955627e-02, 9.77016270e-01],
#        [6.98414743e-01, 2.74417326e-02, 2.14972660e-01, 5.91707528e-02],
#        [9.96146083e-01, 2.39986717e-03, 1.35173020e-03, 1.02343896e-04],
#        [6.37224078e-01, 2.05985814e-01, 1.29594784e-02, 1.43830702e-01],
#        [2.06402317e-02, 7.56385503e-03, 1.24834254e-02, 9.59312439e-01],
#        [5.09057283e-01, 3.24883223e-01, 1.02117285e-01, 6.39422685e-02],
#        [2.29602465e-05, 7.48062412e-09, 9.98108983e-01, 1.86799583e-03],
#        [3.70643139e-02, 9.57813561e-01, 3.61445220e-03, 1.50762836e-03],
#        [6.52261898e-02, 2.87766811e-02, 4.18362975e-01, 4.87634182e-01],
#        [8.11716259e-01, 3.50620262e-02, 1.04637682e-01, 4.85840291e-02],
#        [2.11968556e-01, 4.69830520e-02, 4.89638597e-01, 2.51409858e-01],
#        [1.04601339e-01, 6.75761886e-03, 7.92579889e-01, 9.60611254e-02],
#        [6.15593083e-02, 2.27399394e-01, 1.12542279e-01, 5.98499060e-01],
#        [1.87555235e-02, 9.54958558e-01, 1.83113315e-03, 2.44548339e-02],
#        [5.01519181e-02, 8.84506583e-01, 1.72139574e-02, 4.81275208e-02],
#        [2.31778026e-02, 4.07175124e-01, 3.49116623e-02, 5.34735382e-01],
#        [5.84434136e-04, 1.59230680e-04, 6.43825233e-01, 3.55431169e-01],
#        [3.59968215e-01, 1.29401470e-02, 3.99967767e-02, 5.87094843e-01],
#        [2.17103064e-02, 6.07644841e-02, 6.01857491e-02, 8.57339442e-01],
#        [1.65840499e-02, 5.95021583e-02, 4.56353009e-01, 4.67560768e-01],
#        [5.31819707e-04, 1.09142502e-05, 9.86935437e-01, 1.25218462e-02],
#        [2.92471232e-04, 7.39874895e-06, 9.39333200e-01, 6.03669174e-02],
#        [3.55985351e-02, 9.04541075e-01, 2.15455964e-02, 3.83147635e-02],
#        [1.58507144e-03, 9.94807541e-01, 3.75494215e-04, 3.23191448e-03],
#        [1.16739729e-02, 1.93971381e-01, 6.65055811e-02, 7.27849126e-01],
#        [9.96288896e-01, 3.54233803e-03, 6.41408551e-05, 1.04621176e-04],
#        [3.36276501e-01, 1.25108644e-01, 1.81235656e-01, 3.57379228e-01],
#        [2.09022053e-02, 7.65117584e-05, 8.75653744e-01, 1.03367530e-01],
#        [1.20081320e-01, 2.68744747e-03, 2.05158144e-01, 6.72073066e-01],
#        [2.25119907e-02, 9.54576373e-01, 4.19712672e-03, 1.87146403e-02],
#        [4.16204274e-01, 5.80172725e-02, 1.55032128e-01, 3.70746315e-01],
#        [2.27450386e-01, 4.23171371e-02, 5.15679240e-01, 2.14553222e-01],
#        [1.66510697e-02, 9.65159774e-01, 3.95497587e-03, 1.42342402e-02],
#        [3.27750862e-01, 1.40278172e-02, 3.62323076e-01, 2.95898318e-01],
#        [1.89355120e-01, 7.82217085e-03, 6.82728291e-01, 1.20094441e-01],
#        [1.76088797e-04, 7.51203333e-04, 5.76671921e-02, 9.41405475e-01],
#        [9.93094683e-01, 5.42628719e-03, 1.09746691e-03, 3.81585880e-04],
#        [1.03594556e-01, 1.58433570e-03, 8.65454555e-01, 2.93666068e-02],
#        [6.14526961e-03, 1.59984697e-02, 2.51986738e-02, 9.52657580e-01],
#        [3.85788262e-01, 5.72462426e-03, 5.09426221e-02, 5.57544470e-01],
#        [2.18526963e-02, 3.41086532e-04, 9.17433083e-01, 6.03731275e-02],
#        [5.13604760e-01, 4.64677095e-01, 1.22236675e-02, 9.49441921e-03],
#        [2.12998055e-02, 9.69646990e-01, 2.22359481e-03, 6.82954350e-03],
#        [3.91445449e-03, 9.93574440e-01, 4.33385023e-04, 2.07774783e-03],
#        [3.55084017e-02, 2.17920728e-03, 3.89076471e-01, 5.73235929e-01],
#        [2.76175048e-02, 2.25768254e-05, 9.62755919e-01, 9.60404146e-03],
#        [2.96786670e-02, 9.53196228e-01, 4.98395879e-03, 1.21412314e-02],
#        [9.93861675e-01, 3.08472943e-03, 1.52301521e-03, 1.53061154e-03],
#        [3.40404138e-02, 9.41907465e-01, 4.22528526e-03, 1.98268946e-02],
#        [4.15544212e-02, 3.19428518e-02, 9.85564068e-02, 8.27946305e-01],
#        [1.40331802e-03, 6.03959961e-06, 9.80393648e-01, 1.81969944e-02],
#        [1.87743884e-02, 1.18804649e-01, 4.15852619e-03, 8.58262420e-01],
#        [3.35492730e-01, 5.53985596e-01, 5.19158468e-02, 5.86058274e-02],
#        [1.11482359e-01, 1.15228564e-01, 3.65170568e-01, 4.08118457e-01],
#        [6.56026483e-01, 2.83411592e-01, 3.31000239e-02, 2.74618939e-02],
#        [7.05753446e-01, 1.95547435e-02, 2.01080255e-02, 2.54583746e-01],
#        [2.50749886e-02, 1.37953053e-03, 2.74592340e-01, 6.98953092e-01],
#        [8.90493218e-04, 1.54564739e-03, 1.69179633e-01, 8.28384221e-01],
#        [1.36642004e-04, 1.45648708e-04, 5.69224451e-03, 9.94025469e-01],
#        [6.48609638e-01, 2.77230233e-01, 1.77463200e-02, 5.64138293e-02],
#        [9.78652298e-01, 3.58356442e-03, 1.51060577e-02, 2.65808799e-03],
#        [1.20400675e-01, 1.71302934e-03, 7.74454415e-01, 1.03431977e-01],
#        [1.25760257e-01, 5.49053669e-01, 3.29360329e-02, 2.92250067e-01],
#        [6.72516529e-04, 1.32878631e-04, 1.32557124e-01, 8.66637468e-01],
#        [4.54150066e-02, 6.76192701e-01, 4.10510004e-02, 2.37341285e-01],
#        [2.19755452e-02, 1.02886779e-03, 4.87450331e-01, 4.89545345e-01],
#        [3.21476124e-02, 4.83848602e-02, 1.40406057e-01, 7.79061437e-01],
#        [2.93328255e-01, 9.65466443e-03, 4.03058887e-01, 2.93958187e-01],
#        [4.89941085e-05, 3.50892748e-04, 6.24183612e-03, 9.93358314e-01],
#        [1.06490648e-03, 1.40949423e-05, 9.88172829e-01, 1.07481666e-02],
#        [2.77492497e-02, 1.37360592e-03, 7.95948267e-01, 1.74928814e-01],
#        [5.31937420e-01, 5.11086807e-02, 3.40465158e-01, 7.64887631e-02],
#        [4.11309987e-01, 1.18771642e-01, 2.05762178e-01, 2.64156222e-01],
#        [9.18115079e-01, 2.17488036e-03, 7.70054385e-02, 2.70463736e-03],
#        [9.99534965e-01, 1.50797641e-04, 2.29590543e-04, 8.46366165e-05],
#        [3.24731171e-02, 7.46092856e-01, 1.17988572e-01, 1.03445373e-01],
#        [6.64853305e-02, 3.92497896e-04, 5.81715524e-01, 3.51406723e-01],
#        [6.05257690e-01, 6.46475777e-02, 2.87440896e-01, 4.26538885e-02],
#        [1.12007754e-02, 1.50463951e-04, 6.47877872e-01, 3.40770870e-01],
#        [2.67369617e-02, 8.26340079e-01, 6.86425120e-02, 7.82803968e-02],
#        [7.98078533e-03, 9.88727212e-01, 6.80455298e-04, 2.61150952e-03],
#        [1.56599712e-02, 3.99541241e-05, 9.80318189e-01, 3.98189761e-03],
#        [3.85503173e-01, 4.03865218e-01, 1.65998731e-02, 1.94031671e-01],
#        [3.20614688e-02, 5.73978585e-04, 1.62073076e-01, 8.05291474e-01],
#        [2.48602897e-01, 3.42327952e-02, 2.09457964e-01, 5.07706344e-01],
#        [2.41075277e-01, 3.48062456e-01, 2.53394544e-01, 1.57467753e-01],
#        [7.98980519e-03, 4.14027425e-04, 8.95187140e-01, 9.64089409e-02],
#        [1.65989518e-03, 1.20152941e-03, 8.04405212e-01, 1.92733377e-01],
#        [7.79727427e-03, 1.39718375e-03, 2.98776835e-01, 6.92028642e-01],
#        [1.38141774e-02, 9.24381733e-01, 2.89791427e-03, 5.89061938e-02],
#        [6.09664977e-01, 2.61514783e-01, 4.48004417e-02, 8.40197727e-02],
#        [1.40825622e-02, 7.06766220e-03, 5.11949003e-01, 4.66900736e-01],
#        [9.92307425e-01, 1.20135339e-03, 4.79850313e-03, 1.69261661e-03],
#        [9.62438345e-01, 8.93069315e-04, 2.75727287e-02, 9.09579080e-03],
#        [3.75557254e-04, 1.25258885e-04, 5.64429983e-02, 9.43056166e-01],
#        [1.84758138e-02, 9.72870827e-01, 8.42206005e-04, 7.81121524e-03],
#        [1.59789994e-02, 9.76856887e-01, 3.55664361e-03, 3.60754342e-03],
#        [1.46197323e-02, 2.81362409e-05, 9.74312425e-01, 1.10396212e-02],
#        [2.07875799e-02, 6.28234863e-01, 1.07417114e-01, 2.43560404e-01],
#        [1.80339590e-01, 2.71200761e-02, 6.27628565e-01, 1.64911732e-01],
#        [8.77516251e-03, 5.11084916e-03, 6.23121336e-02, 9.23801899e-01]],
#       dtype=float32)

# %%
from sklearn.metrics import classification_report
total_acc_test, total_count_test, n_batches_test, loss = 0, 0, 0, 0

#[TO COMPLETE]
y_true = []
y_pred = []

with torch.no_grad():
  for idx, (label, text) in enumerate(dataloader_test):
    logits = gs.best_estimator_.predict_proba(text)
    logits = torch.from_numpy(logits).to(device)

    loss += criterion(logits, label)
    n_batches_test += 1

    total_acc_test += (logits.argmax(1) == label).sum().item()
    total_count_test += label.size(0)

    y_true.extend(label.tolist())
    y_pred.extend(logits.argmax(1).tolist())

accuracy_test = total_acc_test/total_count_test

print(f"Test Accuracy: {100*accuracy_test:.4f}%")
print(classification_report(y_true, y_pred))
# Out:
# Test Accuracy: 84.2000%
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.84       258
#            1       0.91      0.89      0.90       272
#            2       0.84      0.77      0.80       232
#            3       0.78      0.86      0.82       238
#
#     accuracy                           0.84      1000
#    macro avg       0.84      0.84      0.84      1000
# weighted avg       0.84      0.84      0.84      1000

# %% [markdown]
# `%ENDCODE`

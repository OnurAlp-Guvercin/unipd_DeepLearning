# %% [markdown]
# #**Deep Learning Homework 2: *Optimize and Train Deep Models***
# ### MSc Computer Science, Data Science, Cybersecurity @UNIPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti, Prof. Nicolò Navarin and Dr. Luca Pasa
# ---
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will learn how to use one of the most popular libraries for Deep Learning, namely [PyTorch 🔥](https://pytorch.org/). Then, we will see how to face a well known problem that is common during the training phase---overfitting on the training set. Finally, we will study how to perform a fair model selection.
#
# <u>Disclaimer</u>: PyTorch is a complex framework actively used by researcher and developers all over the word. It is highly customizable and there are many other packages build along it. The pourpouse of this and the next homeworks is not to go into all the details of its functionalities, but rather to give you an overview of its applications and understand its rationale. There are many good tutorials online and we suggest you to look at the official [Learn the Basics Tutorial](https://pytorch.org/tutorials/beginner/basics/intro.html), in particular if you are not familiar with other Deep Learning Frameworks.
#
# We hope that you will be able to use PyTorch by yourself for your future projects!
# ---
# ##**Important Instructions for Submissions:**
#
# Generally, in the homeworks, you will be either required to complete a part of Python code or to answer questions in text cells. Code and text cells where you are expected to write your answers have been marked by `%STARTCODE` and `%ENDCODE` or `%STARTEXT` and `%ENDTEXT` tags, respectively. Note that you should never change, move or remove these two tags, otherwise your answers will be __not__ valid. As you will see in this notebook, each cell that includes a `[TO COMPLETE]` part has been put between these placeholders.

# %% [markdown]
# ## Requirements

# %% [markdown]
# In this first exercise we will develop a deep feed forward neural network to perform text classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
# They've just released torch 2.0, but we will use the more stable torch=1.13 along with other supporting libriaries
# !pip3 install datasets skorch pandas~=1.5 torch~=1.13 torchinfo torchdata~=0.5 torchtext~=0.14 torchvision~=0.14 torchaudio~=0.13

# %% [markdown]
# ##Imports

# %%
import torch
import torch.nn.functional as F
from torchinfo import summary
from torchtext.datasets import AG_NEWS
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import nn
from sklearn.model_selection import GridSearchCV
from skorch import NeuralNetClassifier 
from skorch.helper import SliceDataset
import multiprocessing
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import logging
import os
from timeit import default_timer as timer

# %%
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

print(f"{torch.__version__=}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"{device=}")
# !nvidia-smi --format=csv --query-gpu=index,name,driver_version,memory.total,memory.used,memory.free

# Set seed for reproducibility
torch.manual_seed(42)
rng = np.random.default_rng(seed=4242)
# Out:
# torch.__version__='1.13.1+cu117'
# device=device(type='cuda')
# index, name, driver_version, memory.total [MiB], memory.used [MiB], memory.free [MiB]
# 0, Tesla T4, 525.85.12, 15360 MiB, 3 MiB, 15098 MiB

# %% [markdown]
# #Data Loading and Preprocessing

# %% [markdown]
# ### Load Data: AG News Subset
#
# In this HW, we use the AG News Subset that is available in Torchtext Datasets. The AG's news topic classification dataset is constructed by choosing the 4 largest topic classes (1-World, 2-Sports, 3-Business, 4-Sci/Tech) from a larger news corpus. The total number of training samples is $120.000$ and testing $7.600$. For resource constraints, we will limit the number of training, validation and test samples to $10.000$, $1.000$ and $1.000$, respectively. Each sample contains both the title and an excerpt of the article, but in this exercise we will use only the excerpt as input.

# %%
train, test = AG_NEWS(root="dataset", split=('train', 'test'))
Tr, Ts = list(train), list(test)
rng.shuffle(Tr)
rng.shuffle(Ts)
len_train, len_val, len_test = 10000, 1000, 1000
train_data, val_data, test_data = Tr[:len_train], Ts[:len_val], Ts[len_val:len_val+len_test]

# %% [markdown]
# And have a look at one sample:

# %%
idx = 10
sample_label, sample_text = train_data[idx]
print(f"Text: {sample_text}")
print(f"Label: {sample_label}")
# Out:
# Text: Cricket: West Indies #39; winning revival LONDON West Indies has won the Champions Trophy, international one-day cricket #39;s second-most important title, beating England by two wickets at The Oval here.
# Label: 2

# %% [markdown]
# ### Data Preprocessing
# We will go though the basic data processing building blocks for raw text string.
# Given a string, the first step is to tokenize the data to prepare it as input for the model. For this purpouse, we will use the basic Tokenizer of PyTorch. As you can see, it just normalizes the text, removes whitespaces and unsupported characters, and outputs a list:

# %%
tokenizer = get_tokenizer('basic_english')
print("Example: ", tokenizer("I am so HAPPY to study Deep Learning! #UNIPD #UniLIFE"))
# Out:
# Example:  ['i', 'am', 'so', 'happy', 'to', 'study', 'deep', 'learning', '!', '#unipd', '#unilife']

# %% [markdown]
# The AG News Subset dataset consists in news headlines---sequences of words. We have to encode each sample in a single tensor with a fixed number of elements, we will build a vocabulary of the headlines in our training set. In other words, we tokenize all the training set, and map each unique word into a number (a.k.a. index). This is necesseray as Neural Networks process numbers, so such vocabulary simply translates between readable words and numbers.

# %%
def create_tokens(dataset):
  for sample in dataset:
    yield tokenizer(sample[1])

# We limit our model to learn from the first 1000 most frequent tokens
vocab = build_vocab_from_iterator(create_tokens(train_data), specials=["<unk>"], max_tokens=1000) # <unk> is the index we use for specials characters ...
vocab.set_default_index(vocab["<unk>"]) # ... and as 0 the default values for tokens out of the vocabulary (OOV)
print(f"Our vocabulary is made of {len(vocab)} tokens-index pairs.")
# Out:
# Our vocabulary is made of 1000 tokens-index pairs.

# %% [markdown]
# This vocabulary was build from the training set. Let us see what it does on our example:

# %%
# Let us define some useful functions to handle tokens and labels
text_pipeline = lambda x: vocab(tokenizer(x)) # function to go from string -> tokens
label_pipeline = lambda x: int(x) - 1 # function to label starting form 0 for indexing

# %%
sample_tokenization = text_pipeline(sample_text)
sample_label_idx = label_pipeline(sample_label)

print(f"Samlpe headline text:\n {sample_text}")
print(f"Sample headline to tokens:\n {sample_tokenization}")
print(f"Label:\n {sample_label}")
print(f"Label index:\n {sample_label_idx}")
# Out:
# Samlpe headline text:
#  Cricket: West Indies #39; winning revival LONDON West Indies has won the Champions Trophy, international one-day cricket #39;s second-most important title, beating England by two wickets at The Oval here.
# Sample headline to tokens:
#  [0, 337, 0, 12, 728, 0, 184, 337, 0, 28, 182, 2, 645, 0, 3, 123, 0, 0, 12, 9, 0, 0, 361, 3, 0, 380, 24, 50, 0, 19, 2, 0, 489, 1]
# Label:
#  2
# Label index:
#  1

# %% [markdown]
# So each word is correctly mapped into a number, where most frequent words come first (see that the preposition "of", which is very frequent, gets translated to the number $6$). Notice also how "Vancouver" takes the default index value of $0$, meaning that is not frequent in the training set.
#
# Neural Netowrks (usually) take input of fixed size, but news aricles have different lenghts! To tackle this issue, one way is to resort to _multi-hot-encoding_ our dataset, means turning it into a tensor of $0$ and $1$. Concretely, this would mean for instance turning the sequence `[3, 5]` into a $1000$-dimensional vector (our vocabulary) that would be all zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
def multi_hot(token_list, n_cat=len(vocab)):
  encoded = [1 if i in token_list else 0 for i in range(n_cat)]
  return encoded

# %% [markdown]
# The next step is building a PyTorch `DataLoader`. Without going too much into the details, a `DataLoader` is the object one uses in the `for` loops when iterating over the data for training or inference. It has some additional benefits and pourpouses over iterating usual lists, such as multiprocessing, data transformation, sampling or shuffling. Don't worry too much for now, as we do this part for you.

# %%
class AGNewsDataset(Dataset):
  def __init__(self, dataset):
    super().__init__()
    self.dataset = dataset
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    label, text = self.dataset[idx]
    lb = label_pipeline(label)
    txt = multi_hot(text_pipeline(text))
    lb, txt = torch.tensor(lb, dtype=torch.uint8, device=device), torch.tensor(txt, dtype=torch.float32, device=device)
    return lb, txt

# %%
train_dataset = AGNewsDataset(train_data)
val_dataset = AGNewsDataset(val_data)
test_dataset = AGNewsDataset(test_data)

# %%
batch_size = 256
dataloader_training = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
dataloader_validation = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
dataloader_test = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Exercise 2.1: Model Definition and Training
# We can now define the 3-layers feed forward model!
# In PyTorch we do that by subclassing `nn.Module`, and initialize the neural network layers in `__init__`. Every `nn.Module` subclass implements the operations on input data in the `forward` method.
#
# In detail, we created a `FeedforwardNetwork` class. The constructor takes three arguments: `input_dim` (an integer), which is the dimension of the input layer; `num_classes` (an integer), which is the number of output classes; and `hidden_layers_dim` (a list of integers), which is the dimension of the hidden layers in the network.
#
# In the constructor, the `nn.ModuleList() ` object is initialized to hold the layers of the network. If `hidden_layers_dim` is an empty list, then the network only consists of a single linear layer (from input to output). Otherwise, the network consists of multiple linear layers. The first layer goes from the input layer to the first hidden layer, and the subsequent hidden layers go from the previous hidden layer to the next hidden layer. The final output layer goes from the last hidden layer to the output layer.
#
# The `_init_weights` function is a helper function that initializes the weights of the linear layers in the network. It initializes the weights using a normal distribution with a mean of 0 and a standard deviation of 0.1, and sets the biases to zero. Notice that there exist other methods available in the `torch.nn.init` module to initialize layers' weights.
#
# The `forward` function defines the forward pass of the network. It first checks whether the network has only one layer (in which case it simply returns the output of that layer). Otherwise, it applies the `relu` activation function to the output of each hidden layer and passes the result to the next layer. Finally, it returns the output of the final layer. We don't apply the softmax function to the logits produced by the network as this will be done internally in the `CrossEntropyLoss` class, as documented [here](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss).

# %%
class FeedforwardNetwork(nn.Module):
  
  def __init__(self, input_dim, num_classes, hidden_layers_dim=[]):
    super().__init__()
    self.layers = nn.ModuleList()
    if len(hidden_layers_dim) == 0:
      self.layers = self.layers.append(nn.Linear(input_dim, num_classes))
    else:
      for layer_idx in range(len(hidden_layers_dim)):
        if layer_idx == 0:  # first layer, from input to hidden
          self.layers = self.layers.append(nn.Linear(input_dim, hidden_layers_dim[layer_idx]))
        else:  # hidden layers, depending on the input
          self.layers = self.layers.append(nn.Linear(hidden_layers_dim[layer_idx-1], hidden_layers_dim[layer_idx]))
          
      self.layers = self.layers.append(nn.Linear(hidden_layers_dim[-1], num_classes))  # final output layer
    self.apply(self._init_weights)
    
  def _init_weights(self, module):
    if isinstance(module, nn.Linear):
        module.weight.data.normal_(mean=0.0, std=.1)
        if module.bias is not None:
            module.bias.data.zero_()
  
  def forward(self, x):
    if len(self.layers) == 1:
      return self.layers[0](x)
    else:
      for layer in self.layers[:-1]:
        x = F.relu(layer(x))
    return self.layers[-1](x)

# %%
# Now we prepare our model for this specific dataset and exercise
num_class = len(set([label for (label, text) in train_data]))
vocab_size = len(vocab)
EPOCHS = 40
lr = 1e-4
model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[64, 64]).to(device)
summary(model, (batch_size, vocab_size)) # Here is a nice summary of our model!
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# FeedforwardNetwork                       [256, 4]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [256, 64]                 64,064
# │    └─Linear: 2-2                       [256, 64]                 4,160
# │    └─Linear: 2-3                       [256, 4]                  260
# ==========================================================================================
# Total params: 68,484
# Trainable params: 68,484
# Non-trainable params: 0
# Total mult-adds (M): 17.53
# ==========================================================================================
# Input size (MB): 1.02
# Forward/backward pass size (MB): 0.27
# Params size (MB): 0.27
# Estimated Total Size (MB): 1.57
# ==========================================================================================

# %%
# We need to define our loss function (Cross Entropy for multiclass classification) and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# Finally, we can define the training procedure. In PyTorch there are few guidelines to follow to train a model. This time try on your own to understand what each line of code is doing, it will be required for the following HWs and exercises!

# %%
def train(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %% [markdown]
# Let's train it!

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 29.19%, Loss: 1.37646139 ---------------- Val_Acc: 31.10%, Val_Loss: 1.36887670
# epoch: 2 -> Accuracy: 36.11%, Loss: 1.35390890 ---------------- Val_Acc: 38.00%, Val_Loss: 1.34807920
# epoch: 3 -> Accuracy: 42.89%, Loss: 1.32762301 ---------------- Val_Acc: 45.40%, Val_Loss: 1.32007623
# epoch: 4 -> Accuracy: 49.58%, Loss: 1.29186273 ---------------- Val_Acc: 51.20%, Val_Loss: 1.28033686
# epoch: 5 -> Accuracy: 56.22%, Loss: 1.24280047 ---------------- Val_Acc: 57.10%, Val_Loss: 1.22511125
# epoch: 6 -> Accuracy: 62.31%, Loss: 1.17782474 ---------------- Val_Acc: 63.50%, Val_Loss: 1.15347004
# epoch: 7 -> Accuracy: 67.06%, Loss: 1.09697926 ---------------- Val_Acc: 67.20%, Val_Loss: 1.06815410
# epoch: 8 -> Accuracy: 70.97%, Loss: 1.00427592 ---------------- Val_Acc: 70.40%, Val_Loss: 0.97537494
# epoch: 9 -> Accuracy: 73.97%, Loss: 0.90765697 ---------------- Val_Acc: 72.80%, Val_Loss: 0.88473141
# epoch: 10 -> Accuracy: 76.16%, Loss: 0.81696790 ---------------- Val_Acc: 75.00%, Val_Loss: 0.80519199
# epoch: 11 -> Accuracy: 77.98%, Loss: 0.73864192 ---------------- Val_Acc: 77.00%, Val_Loss: 0.74046600
# epoch: 12 -> Accuracy: 79.40%, Loss: 0.67405695 ---------------- Val_Acc: 77.80%, Val_Loss: 0.68985057
# epoch: 13 -> Accuracy: 80.57%, Loss: 0.62171483 ---------------- Val_Acc: 78.60%, Val_Loss: 0.65083522
# epoch: 14 -> Accuracy: 81.49%, Loss: 0.57953066 ---------------- Val_Acc: 79.10%, Val_Loss: 0.62090379
# epoch: 15 -> Accuracy: 82.40%, Loss: 0.54525894 ---------------- Val_Acc: 79.50%, Val_Loss: 0.59777582
# epoch: 16 -> Accuracy: 83.17%, Loss: 0.51701438 ---------------- Val_Acc: 80.80%, Val_Loss: 0.57981026
# epoch: 17 -> Accuracy: 83.83%, Loss: 0.49333045 ---------------- Val_Acc: 81.30%, Val_Loss: 0.56550682
# epoch: 18 -> Accuracy: 84.36%, Loss: 0.47320190 ---------------- Val_Acc: 81.80%, Val_Loss: 0.55399346
# epoch: 19 -> Accuracy: 84.85%, Loss: 0.45581070 ---------------- Val_Acc: 82.50%, Val_Loss: 0.54458970
# epoch: 20 -> Accuracy: 85.24%, Loss: 0.44056699 ---------------- Val_Acc: 82.60%, Val_Loss: 0.53681171
# epoch: 21 -> Accuracy: 85.59%, Loss: 0.42702815 ---------------- Val_Acc: 82.70%, Val_Loss: 0.53031856
# epoch: 22 -> Accuracy: 86.05%, Loss: 0.41488034 ---------------- Val_Acc: 83.20%, Val_Loss: 0.52483881
# epoch: 23 -> Accuracy: 86.36%, Loss: 0.40387246 ---------------- Val_Acc: 83.50%, Val_Loss: 0.52022433
# epoch: 24 -> Accuracy: 86.74%, Loss: 0.39380559 ---------------- Val_Acc: 83.40%, Val_Loss: 0.51632607
# epoch: 25 -> Accuracy: 86.99%, Loss: 0.38452145 ---------------- Val_Acc: 83.30%, Val_Loss: 0.51299566
# epoch: 26 -> Accuracy: 87.23%, Loss: 0.37591565 ---------------- Val_Acc: 83.30%, Val_Loss: 0.51019174
# epoch: 27 -> Accuracy: 87.52%, Loss: 0.36789200 ---------------- Val_Acc: 83.30%, Val_Loss: 0.50785363
# epoch: 28 -> Accuracy: 87.74%, Loss: 0.36036891 ---------------- Val_Acc: 83.30%, Val_Loss: 0.50588977
# epoch: 29 -> Accuracy: 88.04%, Loss: 0.35328457 ---------------- Val_Acc: 83.60%, Val_Loss: 0.50423431
# epoch: 30 -> Accuracy: 88.22%, Loss: 0.34658787 ---------------- Val_Acc: 83.30%, Val_Loss: 0.50289893
# epoch: 31 -> Accuracy: 88.45%, Loss: 0.34023497 ---------------- Val_Acc: 83.30%, Val_Loss: 0.50181830
# epoch: 32 -> Accuracy: 88.63%, Loss: 0.33418489 ---------------- Val_Acc: 83.10%, Val_Loss: 0.50100064
# epoch: 33 -> Accuracy: 88.91%, Loss: 0.32841519 ---------------- Val_Acc: 83.00%, Val_Loss: 0.50038666
# epoch: 34 -> Accuracy: 89.01%, Loss: 0.32289478 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49993789
# epoch: 35 -> Accuracy: 89.23%, Loss: 0.31759977 ---------------- Val_Acc: 82.70%, Val_Loss: 0.49972332
# epoch: 36 -> Accuracy: 89.29%, Loss: 0.31251654 ---------------- Val_Acc: 82.70%, Val_Loss: 0.49966303
# epoch: 37 -> Accuracy: 89.45%, Loss: 0.30762905 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49973947
# epoch: 38 -> Accuracy: 89.54%, Loss: 0.30291182 ---------------- Val_Acc: 82.80%, Val_Loss: 0.49995774
# epoch: 39 -> Accuracy: 89.65%, Loss: 0.29835397 ---------------- Val_Acc: 82.70%, Val_Loss: 0.50035971
# epoch: 40 -> Accuracy: 89.78%, Loss: 0.29393932 ---------------- Val_Acc: 82.80%, Val_Loss: 0.50090587
# Training time in second: 231.38857876700013

# %% [markdown]
# We can now plot these results:

# %%
def plot_learning_acc_and_loss(loss_tr, acc_tr, loss_val, acc_val):
    info = {'loss_training':loss_tr,'acc_trainig':acc_tr, 'loss_validation':loss_val, 'acc_validation':acc_val}
    df = pd.DataFrame(info)
    df.plot(figsize=(8, 10), subplots=[('acc_trainig', 'acc_validation'), ('loss_training','loss_validation')], grid=True)
    plt.xlabel("Epochs")
    plt.show()
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set. By having a look at the previous code, compute the performances on the test set.

# %% [markdown]
# `%STARTCODE`

# %%
model.eval()
total_acc_test, total_count_test, n_batches_test, loss = 0, 0, 0, 0

#[TO COMPLETE]
with torch.no_grad():
  for idx, (label, text) in enumerate(dataloader_test):
    logits = model(text)

    loss += criterion(logits, label)
    n_batches_test += 1

    total_acc_test += (logits.argmax(1) == label).sum().item()
    total_count_test += label.size(0)

loss_test = loss/n_batches_test
accuracy_test = total_acc_test/total_count_test

print(f"Test Loss: {loss_test:.8f}", end=' ---------- ')
print(f"Test Accuracy: {100*accuracy_test:.4f}%")
# Out:
# Test Loss: 0.41515473 ---------- Test Accuracy: 86.0000%

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in the next cell.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# Answer: **[TO COMLPETE]**
#
# We need to understand if our model is overfit or underfit via looking validation set, and if we see some problem we can change model hyperparameters and tune it. We cannot use test set in place of validation set because we also need a set to test our model and it shouldnt be seen by model in the training procedure. Otherwise it could result unfair results. Validation set is useful for detecting overfit or underfit in our model and tuning it.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not much overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %% [markdown]
# ## [TO COMPLETE] Overfitting Model
# In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %% [markdown]
# `%STARTCODE`

# %%
EPOCHS = 50 #[TO COMPLETE]
lr = 0.01 #[TO COMPLETE]
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[64,64,64,64]).to(device) #[TO COMPLETE]
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       64,064
# │    └─Linear: 2-2                       4,160
# │    └─Linear: 2-3                       4,160
# │    └─Linear: 2-4                       4,160
# │    └─Linear: 2-5                       260
# =================================================================
# Total params: 76,804
# Trainable params: 76,804
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 69.42%, Loss: 0.73818266 ---------------- Val_Acc: 81.80%, Val_Loss: 0.52584136
# epoch: 2 -> Accuracy: 87.56%, Loss: 0.36282325 ---------------- Val_Acc: 81.60%, Val_Loss: 0.56572211
# epoch: 3 -> Accuracy: 91.31%, Loss: 0.25445250 ---------------- Val_Acc: 79.80%, Val_Loss: 0.68000555
# epoch: 4 -> Accuracy: 92.90%, Loss: 0.21592493 ---------------- Val_Acc: 79.00%, Val_Loss: 0.83584821
# epoch: 5 -> Accuracy: 91.88%, Loss: 0.24287418 ---------------- Val_Acc: 79.90%, Val_Loss: 0.81368101
# epoch: 6 -> Accuracy: 94.67%, Loss: 0.15261857 ---------------- Val_Acc: 81.90%, Val_Loss: 0.88145947
# epoch: 7 -> Accuracy: 97.74%, Loss: 0.06779367 ---------------- Val_Acc: 80.20%, Val_Loss: 1.06128478
# epoch: 8 -> Accuracy: 97.98%, Loss: 0.05924834 ---------------- Val_Acc: 80.90%, Val_Loss: 1.06670821
# epoch: 9 -> Accuracy: 99.18%, Loss: 0.02327176 ---------------- Val_Acc: 80.90%, Val_Loss: 1.41452575
# epoch: 10 -> Accuracy: 98.96%, Loss: 0.03359007 ---------------- Val_Acc: 82.00%, Val_Loss: 1.17463517
# epoch: 11 -> Accuracy: 99.35%, Loss: 0.02275127 ---------------- Val_Acc: 81.30%, Val_Loss: 1.35849822
# epoch: 12 -> Accuracy: 99.49%, Loss: 0.01433350 ---------------- Val_Acc: 80.00%, Val_Loss: 1.74225855
# epoch: 13 -> Accuracy: 99.33%, Loss: 0.02090927 ---------------- Val_Acc: 81.10%, Val_Loss: 1.63953245
# epoch: 14 -> Accuracy: 99.26%, Loss: 0.02244460 ---------------- Val_Acc: 81.70%, Val_Loss: 1.46395659
# epoch: 15 -> Accuracy: 99.45%, Loss: 0.01646711 ---------------- Val_Acc: 80.40%, Val_Loss: 1.48779011
# epoch: 16 -> Accuracy: 99.38%, Loss: 0.01782973 ---------------- Val_Acc: 81.10%, Val_Loss: 1.37080741
# epoch: 17 -> Accuracy: 99.57%, Loss: 0.01223515 ---------------- Val_Acc: 80.40%, Val_Loss: 1.59433234
# epoch: 18 -> Accuracy: 99.67%, Loss: 0.01183410 ---------------- Val_Acc: 81.30%, Val_Loss: 1.60755897
# epoch: 19 -> Accuracy: 99.73%, Loss: 0.00920952 ---------------- Val_Acc: 81.90%, Val_Loss: 1.58813810
# epoch: 20 -> Accuracy: 99.70%, Loss: 0.00835871 ---------------- Val_Acc: 80.60%, Val_Loss: 1.71251535
# epoch: 21 -> Accuracy: 99.58%, Loss: 0.01409437 ---------------- Val_Acc: 82.40%, Val_Loss: 1.66753507
# epoch: 22 -> Accuracy: 99.50%, Loss: 0.01558056 ---------------- Val_Acc: 81.30%, Val_Loss: 1.66027713
# epoch: 23 -> Accuracy: 99.49%, Loss: 0.01464203 ---------------- Val_Acc: 80.40%, Val_Loss: 1.75598645
# epoch: 24 -> Accuracy: 99.25%, Loss: 0.02135370 ---------------- Val_Acc: 80.70%, Val_Loss: 1.51258302
# epoch: 25 -> Accuracy: 99.44%, Loss: 0.01974609 ---------------- Val_Acc: 80.70%, Val_Loss: 1.63416970
# epoch: 26 -> Accuracy: 99.24%, Loss: 0.02134978 ---------------- Val_Acc: 80.10%, Val_Loss: 1.59094143
# epoch: 27 -> Accuracy: 99.71%, Loss: 0.00912501 ---------------- Val_Acc: 82.40%, Val_Loss: 1.82069433
# epoch: 28 -> Accuracy: 99.82%, Loss: 0.00677794 ---------------- Val_Acc: 81.30%, Val_Loss: 1.70531416
# epoch: 29 -> Accuracy: 99.83%, Loss: 0.00462625 ---------------- Val_Acc: 81.00%, Val_Loss: 1.98071623
# epoch: 30 -> Accuracy: 99.75%, Loss: 0.00754600 ---------------- Val_Acc: 80.30%, Val_Loss: 2.22097683
# epoch: 31 -> Accuracy: 99.56%, Loss: 0.01553285 ---------------- Val_Acc: 79.90%, Val_Loss: 1.79819775
# epoch: 32 -> Accuracy: 99.51%, Loss: 0.01590006 ---------------- Val_Acc: 79.80%, Val_Loss: 1.93506479
# epoch: 33 -> Accuracy: 99.68%, Loss: 0.00944686 ---------------- Val_Acc: 79.50%, Val_Loss: 2.19637918
# epoch: 34 -> Accuracy: 99.52%, Loss: 0.01594293 ---------------- Val_Acc: 79.70%, Val_Loss: 2.09217024
# epoch: 35 -> Accuracy: 99.58%, Loss: 0.01288866 ---------------- Val_Acc: 80.50%, Val_Loss: 1.98130310
# epoch: 36 -> Accuracy: 99.58%, Loss: 0.01281373 ---------------- Val_Acc: 81.40%, Val_Loss: 2.07672930
# epoch: 37 -> Accuracy: 99.68%, Loss: 0.00957483 ---------------- Val_Acc: 81.30%, Val_Loss: 2.09457731
# epoch: 38 -> Accuracy: 99.82%, Loss: 0.00621887 ---------------- Val_Acc: 79.10%, Val_Loss: 2.58904338
# epoch: 39 -> Accuracy: 99.57%, Loss: 0.01431251 ---------------- Val_Acc: 79.80%, Val_Loss: 2.31087065
# epoch: 40 -> Accuracy: 99.46%, Loss: 0.01947885 ---------------- Val_Acc: 79.30%, Val_Loss: 2.96204185
# Training time in second: 230.56162434099997

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.3: $L^1$- and $L^2$-regularization
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \lambda L^p(\theta)
# $$
# where $\lambda$ is a hyperparameter that weighs the relative contribution of the norm penalty $L^p$ on a lernable parameter vector $\theta$:
# $$
#  L^p(\theta)=||\theta||_p=\left(\sum_i |\theta_i|^p\right)^{1/p}
# $$

# %% [markdown]
# In the following blocks you should implement both the $L^1$ and $L^2$ regularization for the overfitting model.
#
# **Disclaimer**: you can implement norms either from scratch (i.e. using simple math operators) or using `torch.linalg` methods, but **not** using implementations embedded in Torch optimizers.

# %% [markdown]
# ### [TO COMPLETE] $L^1$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L1(model, optimizer, dataloader_train, dataloader_val, l1_lambda=0.001, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      sum_of_params = 0.0
      for param in model.parameters():
        if param.requires_grad:
          sum_of_params += torch.sum(torch.abs(param))
      loss_with_l1 = loss + l1_lambda * sum_of_params
      ##########################################################
      total_loss_train += loss
      loss_with_l1.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L1(overfit_model, optimizer, dataloader_training, dataloader_validation, l1_lambda=0.001)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 26.85%, Loss: 1.38745439 ---------------- Val_Acc: 28.60%, Val_Loss: 1.37772405
# epoch: 2 -> Accuracy: 30.68%, Loss: 1.37110841 ---------------- Val_Acc: 32.80%, Val_Loss: 1.36397564
# epoch: 3 -> Accuracy: 34.21%, Loss: 1.35785460 ---------------- Val_Acc: 35.50%, Val_Loss: 1.35014343
# epoch: 4 -> Accuracy: 37.34%, Loss: 1.34250247 ---------------- Val_Acc: 41.70%, Val_Loss: 1.33306372
# epoch: 5 -> Accuracy: 40.97%, Loss: 1.32335091 ---------------- Val_Acc: 45.40%, Val_Loss: 1.31084871
# epoch: 6 -> Accuracy: 45.54%, Loss: 1.29824376 ---------------- Val_Acc: 49.40%, Val_Loss: 1.28189123
# epoch: 7 -> Accuracy: 49.31%, Loss: 1.26529574 ---------------- Val_Acc: 53.10%, Val_Loss: 1.24414539
# epoch: 8 -> Accuracy: 53.32%, Loss: 1.22271633 ---------------- Val_Acc: 57.40%, Val_Loss: 1.19615436
# epoch: 9 -> Accuracy: 57.08%, Loss: 1.16920793 ---------------- Val_Acc: 60.10%, Val_Loss: 1.13859129
# epoch: 10 -> Accuracy: 60.62%, Loss: 1.10515833 ---------------- Val_Acc: 63.10%, Val_Loss: 1.07373083
# epoch: 11 -> Accuracy: 63.70%, Loss: 1.03452098 ---------------- Val_Acc: 65.90%, Val_Loss: 1.00658584
# epoch: 12 -> Accuracy: 66.09%, Loss: 0.96365941 ---------------- Val_Acc: 68.40%, Val_Loss: 0.94332564
# epoch: 13 -> Accuracy: 68.72%, Loss: 0.89809954 ---------------- Val_Acc: 70.00%, Val_Loss: 0.88796574
# epoch: 14 -> Accuracy: 70.77%, Loss: 0.84048378 ---------------- Val_Acc: 72.20%, Val_Loss: 0.84109378
# epoch: 15 -> Accuracy: 72.27%, Loss: 0.79123944 ---------------- Val_Acc: 72.70%, Val_Loss: 0.80239636
# epoch: 16 -> Accuracy: 73.86%, Loss: 0.74964553 ---------------- Val_Acc: 73.10%, Val_Loss: 0.77044547
# epoch: 17 -> Accuracy: 75.33%, Loss: 0.71449471 ---------------- Val_Acc: 74.80%, Val_Loss: 0.74387074
# epoch: 18 -> Accuracy: 76.46%, Loss: 0.68480778 ---------------- Val_Acc: 75.10%, Val_Loss: 0.72199035
# epoch: 19 -> Accuracy: 77.50%, Loss: 0.65958190 ---------------- Val_Acc: 76.10%, Val_Loss: 0.70348132
# epoch: 20 -> Accuracy: 78.26%, Loss: 0.63799781 ---------------- Val_Acc: 76.70%, Val_Loss: 0.68780887
# epoch: 21 -> Accuracy: 79.07%, Loss: 0.61935562 ---------------- Val_Acc: 76.80%, Val_Loss: 0.67432839
# epoch: 22 -> Accuracy: 79.75%, Loss: 0.60315984 ---------------- Val_Acc: 76.80%, Val_Loss: 0.66282040
# epoch: 23 -> Accuracy: 80.21%, Loss: 0.58907056 ---------------- Val_Acc: 77.00%, Val_Loss: 0.65281117
# epoch: 24 -> Accuracy: 80.67%, Loss: 0.57671225 ---------------- Val_Acc: 77.10%, Val_Loss: 0.64429569
# epoch: 25 -> Accuracy: 81.00%, Loss: 0.56582183 ---------------- Val_Acc: 77.40%, Val_Loss: 0.63693011
# epoch: 26 -> Accuracy: 81.39%, Loss: 0.55622596 ---------------- Val_Acc: 77.30%, Val_Loss: 0.63045204
# epoch: 27 -> Accuracy: 81.64%, Loss: 0.54770696 ---------------- Val_Acc: 77.30%, Val_Loss: 0.62477148
# epoch: 28 -> Accuracy: 81.99%, Loss: 0.54001313 ---------------- Val_Acc: 77.70%, Val_Loss: 0.61968505
# epoch: 29 -> Accuracy: 82.20%, Loss: 0.53300738 ---------------- Val_Acc: 77.90%, Val_Loss: 0.61497557
# epoch: 30 -> Accuracy: 82.48%, Loss: 0.52664292 ---------------- Val_Acc: 77.90%, Val_Loss: 0.61073661
# epoch: 31 -> Accuracy: 82.78%, Loss: 0.52086657 ---------------- Val_Acc: 78.20%, Val_Loss: 0.60676146
# epoch: 32 -> Accuracy: 82.88%, Loss: 0.51564693 ---------------- Val_Acc: 78.80%, Val_Loss: 0.60297447
# epoch: 33 -> Accuracy: 83.07%, Loss: 0.51086241 ---------------- Val_Acc: 79.10%, Val_Loss: 0.59951347
# epoch: 34 -> Accuracy: 83.18%, Loss: 0.50647038 ---------------- Val_Acc: 79.30%, Val_Loss: 0.59630448
# epoch: 35 -> Accuracy: 83.24%, Loss: 0.50239891 ---------------- Val_Acc: 79.10%, Val_Loss: 0.59326851
# epoch: 36 -> Accuracy: 83.34%, Loss: 0.49865848 ---------------- Val_Acc: 79.10%, Val_Loss: 0.59049797
# epoch: 37 -> Accuracy: 83.37%, Loss: 0.49519762 ---------------- Val_Acc: 79.30%, Val_Loss: 0.58775532
# epoch: 38 -> Accuracy: 83.47%, Loss: 0.49197856 ---------------- Val_Acc: 79.60%, Val_Loss: 0.58514917
# epoch: 39 -> Accuracy: 83.51%, Loss: 0.48895356 ---------------- Val_Acc: 79.80%, Val_Loss: 0.58269268
# epoch: 40 -> Accuracy: 83.65%, Loss: 0.48609361 ---------------- Val_Acc: 79.70%, Val_Loss: 0.58042717
# epoch: 41 -> Accuracy: 83.76%, Loss: 0.48339382 ---------------- Val_Acc: 79.70%, Val_Loss: 0.57817680
# epoch: 42 -> Accuracy: 83.85%, Loss: 0.48080045 ---------------- Val_Acc: 79.90%, Val_Loss: 0.57601899
# epoch: 43 -> Accuracy: 83.92%, Loss: 0.47830740 ---------------- Val_Acc: 80.00%, Val_Loss: 0.57393014
# epoch: 44 -> Accuracy: 83.93%, Loss: 0.47592291 ---------------- Val_Acc: 80.00%, Val_Loss: 0.57195944
# epoch: 45 -> Accuracy: 84.03%, Loss: 0.47363901 ---------------- Val_Acc: 80.00%, Val_Loss: 0.57016730
# epoch: 46 -> Accuracy: 84.11%, Loss: 0.47144756 ---------------- Val_Acc: 80.00%, Val_Loss: 0.56835848
# epoch: 47 -> Accuracy: 84.20%, Loss: 0.46932331 ---------------- Val_Acc: 80.30%, Val_Loss: 0.56659114
# epoch: 48 -> Accuracy: 84.31%, Loss: 0.46727601 ---------------- Val_Acc: 80.20%, Val_Loss: 0.56488860
# epoch: 49 -> Accuracy: 84.40%, Loss: 0.46527845 ---------------- Val_Acc: 80.10%, Val_Loss: 0.56321901
# epoch: 50 -> Accuracy: 84.46%, Loss: 0.46336541 ---------------- Val_Acc: 80.10%, Val_Loss: 0.56169444
# Training time in second: 288.9417989220001

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# ### [TO COMPLETE] $L^2$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L2(model, optimizer, dataloader_train, dataloader_val, l2_lambda=0.001, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      sum_of_params = 0.0
      for param in model.parameters():
        if param.requires_grad:
          sum_of_params += torch.sum(torch.square(param))
      sum_of_params = torch.sqrt(sum_of_params)
      loss_with_l2 = loss + l2_lambda * sum_of_params
      ##########################################################
      total_loss_train += loss
      loss_with_l2.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L2(overfit_model, optimizer, dataloader_training, dataloader_validation, l2_lambda=0.01)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 29.47%, Loss: 1.38519514 ---------------- Val_Acc: 33.90%, Val_Loss: 1.36133218
# epoch: 2 -> Accuracy: 42.42%, Loss: 1.32254267 ---------------- Val_Acc: 46.20%, Val_Loss: 1.30611777
# epoch: 3 -> Accuracy: 54.53%, Loss: 1.24864829 ---------------- Val_Acc: 56.50%, Val_Loss: 1.21936297
# epoch: 4 -> Accuracy: 63.38%, Loss: 1.13263535 ---------------- Val_Acc: 65.00%, Val_Loss: 1.08577573
# epoch: 5 -> Accuracy: 70.26%, Loss: 0.97061187 ---------------- Val_Acc: 70.20%, Val_Loss: 0.92337584
# epoch: 6 -> Accuracy: 75.17%, Loss: 0.79997116 ---------------- Val_Acc: 74.60%, Val_Loss: 0.78362358
# epoch: 7 -> Accuracy: 78.74%, Loss: 0.66400856 ---------------- Val_Acc: 77.00%, Val_Loss: 0.69117248
# epoch: 8 -> Accuracy: 81.12%, Loss: 0.57095212 ---------------- Val_Acc: 77.80%, Val_Loss: 0.63699007
# epoch: 9 -> Accuracy: 82.85%, Loss: 0.50802428 ---------------- Val_Acc: 78.70%, Val_Loss: 0.60411280
# epoch: 10 -> Accuracy: 84.35%, Loss: 0.46281624 ---------------- Val_Acc: 79.60%, Val_Loss: 0.58277535
# epoch: 11 -> Accuracy: 85.40%, Loss: 0.42801023 ---------------- Val_Acc: 80.30%, Val_Loss: 0.56829166
# epoch: 12 -> Accuracy: 86.40%, Loss: 0.39962038 ---------------- Val_Acc: 80.70%, Val_Loss: 0.55820096
# epoch: 13 -> Accuracy: 87.25%, Loss: 0.37545297 ---------------- Val_Acc: 81.00%, Val_Loss: 0.55092061
# epoch: 14 -> Accuracy: 87.88%, Loss: 0.35423607 ---------------- Val_Acc: 81.00%, Val_Loss: 0.54562193
# epoch: 15 -> Accuracy: 88.40%, Loss: 0.33526373 ---------------- Val_Acc: 81.10%, Val_Loss: 0.54193425
# epoch: 16 -> Accuracy: 89.07%, Loss: 0.31799558 ---------------- Val_Acc: 81.20%, Val_Loss: 0.53957653
# epoch: 17 -> Accuracy: 89.66%, Loss: 0.30211413 ---------------- Val_Acc: 81.20%, Val_Loss: 0.53854227
# epoch: 18 -> Accuracy: 90.21%, Loss: 0.28729624 ---------------- Val_Acc: 81.50%, Val_Loss: 0.53843391
# epoch: 19 -> Accuracy: 90.77%, Loss: 0.27336594 ---------------- Val_Acc: 81.70%, Val_Loss: 0.53909010
# epoch: 20 -> Accuracy: 91.27%, Loss: 0.26018330 ---------------- Val_Acc: 81.60%, Val_Loss: 0.54056358
# epoch: 21 -> Accuracy: 91.83%, Loss: 0.24762753 ---------------- Val_Acc: 81.50%, Val_Loss: 0.54284364
# epoch: 22 -> Accuracy: 92.36%, Loss: 0.23560348 ---------------- Val_Acc: 81.70%, Val_Loss: 0.54568464
# epoch: 23 -> Accuracy: 92.81%, Loss: 0.22404389 ---------------- Val_Acc: 81.60%, Val_Loss: 0.54922175
# epoch: 24 -> Accuracy: 93.35%, Loss: 0.21287289 ---------------- Val_Acc: 81.30%, Val_Loss: 0.55357236
# epoch: 25 -> Accuracy: 93.78%, Loss: 0.20205529 ---------------- Val_Acc: 81.40%, Val_Loss: 0.55841386
# epoch: 26 -> Accuracy: 94.20%, Loss: 0.19159381 ---------------- Val_Acc: 81.30%, Val_Loss: 0.56384003
# epoch: 27 -> Accuracy: 94.55%, Loss: 0.18141936 ---------------- Val_Acc: 81.60%, Val_Loss: 0.56979811
# epoch: 28 -> Accuracy: 94.95%, Loss: 0.17153044 ---------------- Val_Acc: 81.50%, Val_Loss: 0.57624018
# epoch: 29 -> Accuracy: 95.28%, Loss: 0.16193086 ---------------- Val_Acc: 81.50%, Val_Loss: 0.58312142
# epoch: 30 -> Accuracy: 95.77%, Loss: 0.15260230 ---------------- Val_Acc: 81.40%, Val_Loss: 0.59051311
# epoch: 31 -> Accuracy: 96.11%, Loss: 0.14354253 ---------------- Val_Acc: 81.60%, Val_Loss: 0.59845012
# epoch: 32 -> Accuracy: 96.46%, Loss: 0.13475017 ---------------- Val_Acc: 81.50%, Val_Loss: 0.60687965
# epoch: 33 -> Accuracy: 96.81%, Loss: 0.12623785 ---------------- Val_Acc: 81.50%, Val_Loss: 0.61559176
# epoch: 34 -> Accuracy: 97.06%, Loss: 0.11802647 ---------------- Val_Acc: 81.30%, Val_Loss: 0.62475824
# epoch: 35 -> Accuracy: 97.35%, Loss: 0.11010666 ---------------- Val_Acc: 81.10%, Val_Loss: 0.63438052
# epoch: 36 -> Accuracy: 97.67%, Loss: 0.10252208 ---------------- Val_Acc: 81.20%, Val_Loss: 0.64437121
# epoch: 37 -> Accuracy: 97.94%, Loss: 0.09528169 ---------------- Val_Acc: 80.90%, Val_Loss: 0.65485245
# epoch: 38 -> Accuracy: 98.18%, Loss: 0.08833221 ---------------- Val_Acc: 81.00%, Val_Loss: 0.66616476
# epoch: 39 -> Accuracy: 98.42%, Loss: 0.08170963 ---------------- Val_Acc: 81.00%, Val_Loss: 0.67744845
# epoch: 40 -> Accuracy: 98.57%, Loss: 0.07541651 ---------------- Val_Acc: 80.70%, Val_Loss: 0.68888009
# Training time in second: 235.23738048999985

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.4: Early Stopping
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (a.k.a. the "patience" or "tolerance" hyper-parameter), it stops the training phase.
#
# To implement it in PyTorch, we define a simple classes that does this job.

# %%
class EarlyStopping:
    def __init__(self, tolerance, min_delta):
        self.tolerance = tolerance
        self.min_delta = min_delta
        self.counter = 0
        self.early_stop = False

    def __call__(self, train_loss, validation_loss):
        if (validation_loss - train_loss) > self.min_delta:
            self.counter +=1
            if self.counter >= self.tolerance:  
                self.early_stop = True

# %% [markdown]
# ## **[TO COMPLETE]**: Define training procedure
# Define a training procedure with Early Stopping and check its performances.

# %% [markdown]
# `%STARTCODE`

# %%
def train_early_stop(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  ###########################################################
  # instantiate an object of the EarlyStopping class 
  #[TO COMPLETE]
  early_stopping = EarlyStopping(5, 0.01)
  ###########################################################
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
    ############################################################
    # Use the EarlyStopping object
    #[TO COMPLETE]
    early_stopping(avg_loss_train, avg_loss_val)
    if early_stopping.early_stop:
      print("early stopping at epoch: ", epoch)
      break
    ############################################################
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_early_stop(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 31.88%, Loss: 1.36826408 ---------------- Val_Acc: 35.60%, Val_Loss: 1.35220981
# epoch: 2 -> Accuracy: 44.94%, Loss: 1.31156957 ---------------- Val_Acc: 49.50%, Val_Loss: 1.29668903
# epoch: 3 -> Accuracy: 56.48%, Loss: 1.23332298 ---------------- Val_Acc: 60.30%, Val_Loss: 1.20622563
# epoch: 4 -> Accuracy: 65.33%, Loss: 1.11052585 ---------------- Val_Acc: 67.30%, Val_Loss: 1.06817901
# epoch: 5 -> Accuracy: 71.21%, Loss: 0.94417298 ---------------- Val_Acc: 71.50%, Val_Loss: 0.90925014
# epoch: 6 -> Accuracy: 76.06%, Loss: 0.77446121 ---------------- Val_Acc: 74.10%, Val_Loss: 0.77445364
# epoch: 7 -> Accuracy: 79.02%, Loss: 0.64385647 ---------------- Val_Acc: 76.10%, Val_Loss: 0.68536347
# epoch: 8 -> Accuracy: 81.25%, Loss: 0.55683225 ---------------- Val_Acc: 77.70%, Val_Loss: 0.63294071
# epoch: 9 -> Accuracy: 82.79%, Loss: 0.49830666 ---------------- Val_Acc: 78.70%, Val_Loss: 0.60068440
# epoch: 10 -> Accuracy: 84.09%, Loss: 0.45585033 ---------------- Val_Acc: 79.80%, Val_Loss: 0.57923913
# epoch: 11 -> Accuracy: 85.03%, Loss: 0.42261782 ---------------- Val_Acc: 79.80%, Val_Loss: 0.56444615
# early stopping at epoch:  10
# Training time in second: 63.278724323999995

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Model Selection
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-5, 1e-4, 1e-3]

# %%
stack = []
for lr in learning_rates:
  print(f"Learning Rate: {lr}")
  model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[128, 64]).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr=lr)
  stack.append(train(model, optimizer, dataloader_training, dataloader_validation, EPOCHS=15))
  print("-"*50)
# Out:
# Learning Rate: 1e-05
# epoch: 1 -> Accuracy: 26.83%, Loss: 1.39657831 ---------------- Val_Acc: 26.90%, Val_Loss: 1.39156842
# epoch: 2 -> Accuracy: 27.73%, Loss: 1.39156950 ---------------- Val_Acc: 28.00%, Val_Loss: 1.38768005
# epoch: 3 -> Accuracy: 28.57%, Loss: 1.38698256 ---------------- Val_Acc: 28.90%, Val_Loss: 1.38398051
# epoch: 4 -> Accuracy: 29.41%, Loss: 1.38262916 ---------------- Val_Acc: 29.90%, Val_Loss: 1.38040924
# epoch: 5 -> Accuracy: 30.15%, Loss: 1.37845457 ---------------- Val_Acc: 31.60%, Val_Loss: 1.37695336
# epoch: 6 -> Accuracy: 31.10%, Loss: 1.37440491 ---------------- Val_Acc: 31.90%, Val_Loss: 1.37357903
# epoch: 7 -> Accuracy: 32.12%, Loss: 1.37043893 ---------------- Val_Acc: 33.10%, Val_Loss: 1.37025285
# epoch: 8 -> Accuracy: 32.91%, Loss: 1.36654842 ---------------- Val_Acc: 33.80%, Val_Loss: 1.36696625
# epoch: 9 -> Accuracy: 34.06%, Loss: 1.36270344 ---------------- Val_Acc: 34.30%, Val_Loss: 1.36369944
# epoch: 10 -> Accuracy: 35.01%, Loss: 1.35888755 ---------------- Val_Acc: 35.00%, Val_Loss: 1.36043406
# epoch: 11 -> Accuracy: 36.15%, Loss: 1.35507882 ---------------- Val_Acc: 35.70%, Val_Loss: 1.35713315
# epoch: 12 -> Accuracy: 37.18%, Loss: 1.35125351 ---------------- Val_Acc: 36.60%, Val_Loss: 1.35379148
# epoch: 13 -> Accuracy: 38.21%, Loss: 1.34739983 ---------------- Val_Acc: 37.80%, Val_Loss: 1.35039234
# epoch: 14 -> Accuracy: 39.35%, Loss: 1.34350479 ---------------- Val_Acc: 38.90%, Val_Loss: 1.34693694
# epoch: 15 -> Accuracy: 40.26%, Loss: 1.33955693 ---------------- Val_Acc: 40.80%, Val_Loss: 1.34341526
# --------------------------------------------------
# Learning Rate: 0.0001
# epoch: 1 -> Accuracy: 28.47%, Loss: 1.37686539 ---------------- Val_Acc: 32.00%, Val_Loss: 1.36353064
# epoch: 2 -> Accuracy: 36.78%, Loss: 1.34462106 ---------------- Val_Acc: 39.30%, Val_Loss: 1.33299816
# epoch: 3 -> Accuracy: 45.80%, Loss: 1.30952871 ---------------- Val_Acc: 48.70%, Val_Loss: 1.29526198
# epoch: 4 -> Accuracy: 54.77%, Loss: 1.26365340 ---------------- Val_Acc: 55.90%, Val_Loss: 1.24458170
# epoch: 5 -> Accuracy: 62.36%, Loss: 1.20187724 ---------------- Val_Acc: 62.00%, Val_Loss: 1.17778480
# epoch: 6 -> Accuracy: 67.92%, Loss: 1.12024021 ---------------- Val_Acc: 66.40%, Val_Loss: 1.09235573
# epoch: 7 -> Accuracy: 72.38%, Loss: 1.01958013 ---------------- Val_Acc: 71.40%, Val_Loss: 0.99216056
# epoch: 8 -> Accuracy: 75.60%, Loss: 0.90852702 ---------------- Val_Acc: 74.80%, Val_Loss: 0.88937736
# epoch: 9 -> Accuracy: 77.78%, Loss: 0.80084050 ---------------- Val_Acc: 76.10%, Val_Loss: 0.79774952
# epoch: 10 -> Accuracy: 79.42%, Loss: 0.70864326 ---------------- Val_Acc: 78.00%, Val_Loss: 0.72508132
# epoch: 11 -> Accuracy: 80.83%, Loss: 0.63587910 ---------------- Val_Acc: 78.60%, Val_Loss: 0.67095315
# epoch: 12 -> Accuracy: 81.94%, Loss: 0.58010960 ---------------- Val_Acc: 79.30%, Val_Loss: 0.63135439
# epoch: 13 -> Accuracy: 82.71%, Loss: 0.53723460 ---------------- Val_Acc: 79.90%, Val_Loss: 0.60213876
# epoch: 14 -> Accuracy: 83.53%, Loss: 0.50344384 ---------------- Val_Acc: 80.60%, Val_Loss: 0.58041561
# epoch: 15 -> Accuracy: 84.36%, Loss: 0.47611666 ---------------- Val_Acc: 80.90%, Val_Loss: 0.56374097
# --------------------------------------------------
# Learning Rate: 0.001
# epoch: 1 -> Accuracy: 53.70%, Loss: 1.17930925 ---------------- Val_Acc: 73.80%, Val_Loss: 0.83899730
# epoch: 2 -> Accuracy: 80.53%, Loss: 0.56797010 ---------------- Val_Acc: 81.50%, Val_Loss: 0.53621364
# epoch: 3 -> Accuracy: 86.23%, Loss: 0.38644096 ---------------- Val_Acc: 81.60%, Val_Loss: 0.50728685
# epoch: 4 -> Accuracy: 89.03%, Loss: 0.31485850 ---------------- Val_Acc: 81.10%, Val_Loss: 0.50711942
# epoch: 5 -> Accuracy: 90.64%, Loss: 0.26555082 ---------------- Val_Acc: 81.60%, Val_Loss: 0.51836932
# epoch: 6 -> Accuracy: 92.36%, Loss: 0.22409938 ---------------- Val_Acc: 81.60%, Val_Loss: 0.53704482
# epoch: 7 -> Accuracy: 93.99%, Loss: 0.18605903 ---------------- Val_Acc: 81.70%, Val_Loss: 0.56034327
# epoch: 8 -> Accuracy: 95.47%, Loss: 0.15045270 ---------------- Val_Acc: 81.60%, Val_Loss: 0.58739781
# epoch: 9 -> Accuracy: 96.95%, Loss: 0.11725763 ---------------- Val_Acc: 81.40%, Val_Loss: 0.61670303
# epoch: 10 -> Accuracy: 98.02%, Loss: 0.08824300 ---------------- Val_Acc: 81.60%, Val_Loss: 0.65108234
# epoch: 11 -> Accuracy: 98.87%, Loss: 0.06491076 ---------------- Val_Acc: 81.40%, Val_Loss: 0.69556665
# epoch: 12 -> Accuracy: 99.40%, Loss: 0.04747027 ---------------- Val_Acc: 81.00%, Val_Loss: 0.74698287
# epoch: 13 -> Accuracy: 99.70%, Loss: 0.03495841 ---------------- Val_Acc: 80.60%, Val_Loss: 0.79372454
# epoch: 14 -> Accuracy: 99.84%, Loss: 0.02639908 ---------------- Val_Acc: 80.40%, Val_Loss: 0.83057332
# epoch: 15 -> Accuracy: 99.86%, Loss: 0.02081500 ---------------- Val_Acc: 81.20%, Val_Loss: 0.88694441
# --------------------------------------------------

# %%
# Let's plot the results
for idx, el in enumerate(stack):
  print(f"Learning Rate: {learning_rates[idx]}")
  plot_learning_acc_and_loss(*el)
# Out:
# Learning Rate: 1e-05
# Learning Rate: 0.0001
# Learning Rate: 0.001

# %% [markdown]
# # Exercise 2.5: Grid Search
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider different possible combinations of values for each hyper-parameter. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be selected.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`, together with some classes from the `skorch` package which allows to use PyTorch models with `scikit-learn`.

# %%
model = NeuralNetClassifier(
    module=FeedforwardNetwork,
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.Adam,
    max_epochs=2)

# we need to adapt PyTorch Dataset to work with Scikit-Learn GridSearchCV
# we use the SliceDataset class from skorch package for this purpose
X_slice = SliceDataset(train_dataset, idx=1)
y_slice = SliceDataset(train_dataset, idx=0)

# %% [markdown]
# ## **[TO COMPLETE]**: Define hyperparameters grid

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use dictionaries of very limited size and hyperparameters, but in a real-world scenario a reasonable amount of possible values should be considered (and there are many other approacehs besisdes Grid-Search).

# %% [markdown]
# `%STARTCODE`

# %%
params = {
    'lr': [1e-5, 1e-4, 1e-3], #[TO COMPLETE],
    'module__input_dim': [vocab_size], #[TO COMPLETE],
    'module__num_classes': [num_class], #[TO COMPLETE],
    'module__hidden_layers_dim':[[128, 64]] #[TO COMPLETE], 
    }

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Now you can use `sklearn`'s `GridSearchCV` to search the hyperparameter space of the `NeuralNetClassifier`:

# %%
n_jobs = multiprocessing.cpu_count()-1
gs = GridSearchCV(model, params, n_jobs=n_jobs)

# %%
outputs = gs.fit(X_slice, y_slice)
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3928       0.2500        1.3933  8.7315
#       2        1.3878       0.2631        1.3887  8.0208
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.4053       0.2494        1.4058  9.6283
#       2        1.3980       0.2537        1.3994  7.5255
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3886       0.2756        1.3897  7.6348
#       2        1.3843       0.2863        1.3860  9.6129
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3945       0.2737        1.3924  7.8098
#       2        1.3890       0.2781        1.3875  9.0293
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3857       0.2894        1.3833  9.6800
#       2        1.3819       0.2938        1.3801  7.2840
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3957       0.3181        1.3705  8.7865
#       2        1.3471       0.4037        1.3321  9.5973
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3814       0.3237        1.3705  7.3064
#       2        1.3487       0.4106        1.3408  9.6233
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3898       0.2988        1.3713  9.7481
#       2        1.3488       0.3931        1.3352  7.2620
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3932       0.3056        1.3721  9.2392
#       2        1.3486       0.4012        1.3329  9.2385
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3842       0.3194        1.3628  7.2121
#       2        1.3373       0.4163        1.3211  9.6411
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1879       0.7494        0.8096  9.4183
#       2        0.5910       0.8475        0.4738  7.4559
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1926       0.7238        0.8614  9.8839
#       2        0.5918       0.8206        0.5345  8.1050
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1845       0.7250        0.8253  7.2117
#       2        0.5664       0.8081        0.5384  9.6380
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1861       0.7238        0.8362  8.4253
#       2        0.5753       0.7987        0.5326  8.3668
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1434       0.7369        0.7948  9.5901
#       2        0.5530       0.8187        0.5226  7.2632
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.0863       0.7685        0.6691  10.3492
#       2        0.4905       0.8275        0.5047  10.2548

# %% [markdown]
# ## **[TO COMPLETE]**: Visualize results
# Print the best hyper-parameters and the performances on the best model on the test set:

# %% [markdown]
# `%STARTCODE`

# %%
print("best score: {:.3f}, best params: {}".format(gs.best_score_, gs.best_params_)) #[TO COMPLETE]
# Out:
# best score: 0.815, best params: {'lr': 0.001, 'module__hidden_layers_dim': [128, 64], 'module__input_dim': 1000, 'module__num_classes': 4}

# %%
gs.best_estimator_.predict_proba(text)

# %%
from sklearn.metrics import classification_report
total_acc_test, total_count_test, n_batches_test, loss = 0, 0, 0, 0

#[TO COMPLETE]
y_true = []
y_pred = []

with torch.no_grad():
  for idx, (label, text) in enumerate(dataloader_test):
    logits = gs.best_estimator_.predict_proba(text)
    logits = torch.from_numpy(logits).to(device)

    loss += criterion(logits, label)
    n_batches_test += 1

    total_acc_test += (logits.argmax(1) == label).sum().item()
    total_count_test += label.size(0)

    y_true.extend(label.tolist())
    y_pred.extend(logits.argmax(1).tolist())

accuracy_test = total_acc_test/total_count_test

print(f"Test Accuracy: {100*accuracy_test:.4f}%")
print(classification_report(y_true, y_pred))
# Out:
# Test Accuracy: 83.7000%
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       261
#            1       0.87      0.94      0.90       251
#            2       0.77      0.78      0.77       237
#            3       0.84      0.75      0.79       251
#
#     accuracy                           0.84      1000
#    macro avg       0.84      0.84      0.83      1000
# weighted avg       0.84      0.84      0.84      1000

# %% [markdown]
# `%ENDCODE`
